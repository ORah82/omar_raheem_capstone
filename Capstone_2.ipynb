# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mbl
from scipy import stats
# %matplotlib inline
from scipy.stats import beta

# %%
from pybaseball import pitching_stats
data = pitching_stats(2016, 2018)
data.head()
# Out:
#      Season              Name       Team   Age     W    L   ERA  WAR     G  \
# 118  2018.0      Jacob deGrom       Mets  30.0  10.0  9.0  1.70  9.0  32.0
# 386  2017.0        Chris Sale    Red Sox  28.0  17.0  8.0  2.90  7.5  32.0
# 254  2018.0      Max Scherzer  Nationals  33.0  18.0  7.0  2.53  7.4  33.0
# 190  2017.0      Corey Kluber    Indians  31.0  18.0  4.0  2.25  7.3  29.0
# 252  2018.0  Justin Verlander     Astros  35.0  16.0  9.0  2.52  6.7  34.0
#
#        GS  ...  wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  \
# 118  32.0  ...        2.25         NaN          0.367          0.661
# 386  32.0  ...        0.67         NaN          0.373          0.619
# 254  33.0  ...        1.85         NaN          0.355          0.666
# 190  29.0  ...        4.65        9.31          0.388          0.595
# 252  34.0  ...        0.48         NaN          0.336          0.656
#
#      Swing% (pi)  O-Contact% (pi)  Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  \
# 118        0.518            0.524            0.804          0.708       0.513
# 386        0.499            0.540            0.798          0.704       0.513
# 254        0.519            0.513            0.774          0.690       0.528
# 190        0.489            0.433            0.853          0.681       0.485
# 252        0.509            0.557            0.785          0.716       0.541
#
#      Pace (pi)
# 118       21.9
# 386       20.9
# 254       24.2
# 190       23.5
# 252       27.0
#
# [5 rows x 299 columns]

# %%
pd.set_option('display.max_columns', 500)
pd.set_option("display.max_rows", 101)

# %%
pd.DataFrame.to_csv(data,"/Users/orah82/baseball_cap/pitching_2016-18.csv")

# %%
data.head()
# Out:
#      Season              Name       Team   Age     W    L   ERA  WAR     G  \
# 118  2018.0      Jacob deGrom       Mets  30.0  10.0  9.0  1.70  9.0  32.0
# 386  2017.0        Chris Sale    Red Sox  28.0  17.0  8.0  2.90  7.5  32.0
# 254  2018.0      Max Scherzer  Nationals  33.0  18.0  7.0  2.53  7.4  33.0
# 190  2017.0      Corey Kluber    Indians  31.0  18.0  4.0  2.25  7.3  29.0
# 252  2018.0  Justin Verlander     Astros  35.0  16.0  9.0  2.52  6.7  34.0
#
#        GS   CG  ShO   SV   BS     IP    TBF      H     R    ER    HR    BB  \
# 118  32.0  1.0  0.0  0.0  0.0  217.0  835.0  152.0  48.0  41.0  10.0  46.0
# 386  32.0  1.0  0.0  0.0  0.0  214.1  851.0  165.0  73.0  69.0  24.0  43.0
# 254  33.0  2.0  1.0  0.0  0.0  220.2  866.0  150.0  66.0  62.0  23.0  51.0
# 190  29.0  5.0  3.0  0.0  0.0  203.2  777.0  141.0  56.0  51.0  21.0  36.0
# 252  34.0  1.0  1.0  0.0  0.0  214.0  833.0  156.0  63.0  60.0  28.0  37.0
#
#      IBB   HBP   WP   BK     SO     GB     FB     LD  IFFB   Balls  Strikes  \
# 118  3.0   5.0  2.0  0.0  269.0  235.0  160.0  111.0  26.0   999.0   2213.0
# 386  0.0   8.0  3.0  0.0  308.0  188.0  199.0   99.0  21.0  1085.0   2343.0
# 254  4.0  12.0  4.0  1.0  300.0  170.0  236.0   90.0  38.0  1087.0   2406.0
# 190  2.0   5.0  4.0  0.0  265.0  208.0  156.0  103.0  18.0   940.0   2005.0
# 252  0.0   8.0  5.0  2.0  290.0  143.0  253.0   96.0  37.0  1063.0   2364.0
#
#      Pitches     RS   IFH   BU  BUH    K/9  BB/9  K/BB   H/9  HR/9    AVG  \
# 118   3212.0   86.0  16.0  9.0  2.0  11.16  1.91  5.85  6.30  0.41  0.194
# 386   3428.0  119.0  16.0  6.0  1.0  12.93  1.81  7.16  6.93  1.01  0.206
# 254   3493.0  139.0  10.0  7.0  1.0  12.24  2.08  5.88  6.12  0.94  0.187
# 190   2945.0  118.0  14.0  4.0  0.0  11.71  1.59  7.36  6.23  0.93  0.192
# 252   3427.0  101.0  18.0  6.0  4.0  12.20  1.56  7.84  6.56  1.18  0.198
#
#      WHIP  BABIP   LOB%   FIP  GB/FB    LD%    GB%  IFFB%  HR/FB   IFH%  \
# 118  0.91  0.281  0.820  1.99   1.47  0.219  0.464  0.163  0.063  0.068
# 386  0.97  0.301  0.784  2.45   0.94  0.204  0.387  0.106  0.121  0.085
# 254  0.91  0.265  0.813  2.65   0.72  0.181  0.343  0.161  0.097  0.059
# 190  0.87  0.267  0.826  2.50   1.33  0.221  0.445  0.115  0.135  0.067
# 252  0.90  0.272  0.853  2.78   0.57  0.195  0.291  0.146  0.111  0.126
#
#       BUH%  Starting  Start-IP  Relieving  Relief-IP   RAR Dollars  tERA  \
# 118  0.222      75.8     217.0        NaN        NaN  75.8   $72.3  2.15
# 386  0.167      68.1     214.1        NaN        NaN  68.1   $60.1  2.72
# 254  0.143      64.1     220.2        NaN        NaN  64.1   $58.8  2.55
# 190  0.000      65.4     203.2        NaN        NaN  65.4   $58.2  2.93
# 252  0.667      60.4     214.0        NaN        NaN  60.4   $53.5  2.61
#
#      xFIP   WPA   -WPA   +WPA   RE24   REW   pLI  inLI  gmLI  exLI  Pulls  \
# 118  2.60  5.85 -12.63  18.48  52.57  5.70  1.14  1.06  0.88  1.01   31.0
# 386  2.65  3.73 -12.36  16.09  38.99  3.83  0.97  0.98  0.86  1.16   31.0
# 254  3.06  4.84 -10.86  15.70  42.84  4.42  0.91  0.93  0.88  0.92   31.0
# 190  2.52  4.72  -9.75  14.47  53.46  5.19  0.91  0.93  0.86  1.14   24.0
# 252  3.03  4.70 -11.73  16.43  40.31  4.16  0.99  1.02  0.87  1.28   33.0
#
#      WPA/LI  Clutch    FB%   FBv    SL%   SLv    CT%   CTv    CB%   CBv  \
# 118    4.62    0.52  0.521  96.0  0.239  91.1    NaN   NaN  0.079  82.7
# 386    4.09   -0.23  0.492  94.4  0.329  79.7    NaN   NaN    NaN   NaN
# 254    4.74    0.58  0.503  94.4  0.164  85.2  0.099  88.6  0.077  78.4
# 190    5.31   -0.13  0.425  92.6    NaN   NaN  0.237  89.0  0.274  84.4
# 252    3.56    1.21  0.613  95.1  0.222  86.5  0.006  91.2  0.144  79.6
#
#        CH%   CHv  SF%  SFv  KN%  KNv    XX%  PO%   wFB   wSL  wCT   wCB   wCH  \
# 118  0.161  89.0  NaN  NaN  NaN  NaN  0.003  NaN  23.9  15.9  NaN   4.6  12.8
# 386  0.179  86.6  NaN  NaN  NaN  NaN    NaN  NaN  28.4   7.8  NaN   NaN   7.4
# 254  0.157  84.0  NaN  NaN  NaN  NaN  0.003  NaN  30.2  10.7 -1.4  -3.4   9.6
# 190  0.065  85.8  NaN  NaN  NaN  NaN  0.003  NaN  -2.3   NaN  9.0  38.2   6.7
# 252  0.015  87.4  NaN  NaN  NaN  NaN    NaN  NaN  30.2   3.9 -2.6   8.6  -2.8
#
#      wSF  wKN  wFB/C  wSL/C  wCT/C  wCB/C  wCH/C  wSF/C  wKN/C  O-Swing%  \
# 118  NaN  NaN   1.43   2.08    NaN   1.81   2.48    NaN    NaN     0.379
# 386  NaN  NaN   1.68   0.69    NaN    NaN   1.21    NaN    NaN     0.362
# 254  NaN  NaN   1.72   1.86  -0.41  -1.27   1.75    NaN    NaN     0.358
# 190  NaN  NaN  -0.18    NaN   1.28   4.73   3.51    NaN    NaN     0.356
# 252  NaN  NaN   1.44   0.51 -13.18   1.73  -5.41    NaN    NaN     0.346
#
#      Z-Swing%  Swing%  O-Contact%  Z-Contact%  Contact%  Zone%  F-Strike%  \
# 118     0.688   0.517       0.577       0.797     0.708  0.446      0.665
# 386     0.656   0.499       0.557       0.792     0.701  0.467      0.668
# 254     0.701   0.520       0.539       0.775     0.690  0.474      0.657
# 190     0.637   0.490       0.449       0.824     0.681  0.478      0.644
# 252     0.688   0.509       0.575       0.794     0.716  0.477      0.689
#
#      SwStr%  HLD   SD   MD  ERA-  FIP-  xFIP-     K%    BB%  SIERA  RS/9  \
# 118   0.151  0.0  0.0  0.0  45.0  49.0   64.0  0.322  0.055   2.78  3.57
# 386   0.149  0.0  0.0  0.0  63.0  56.0   60.0  0.362  0.051   2.58  5.00
# 254   0.162  0.0  0.0  0.0  62.0  65.0   75.0  0.346  0.059   2.71  5.67
# 190   0.156  0.0  0.0  0.0  49.0  56.0   57.0  0.341  0.046   2.68  5.21
# 252   0.145  0.0  0.0  0.0  62.0  67.0   72.0  0.348  0.044   2.63  4.25
#
#       E-F  FA% (pfx)  FT% (pfx)  FC% (pfx)  FS% (pfx)  FO% (pfx)  SI% (pfx)  \
# 118 -0.29      0.435      0.089        NaN        NaN        NaN        NaN
# 386  0.44      0.329      0.169        NaN        NaN        NaN        NaN
# 254 -0.12      0.502        NaN      0.101        NaN        NaN        NaN
# 190 -0.25      0.142        NaN      0.207        NaN        NaN      0.291
# 252 -0.26      0.612        NaN      0.006        NaN        NaN        NaN
#
#      SL% (pfx)  CU% (pfx)  KC% (pfx)  EP% (pfx)  CH% (pfx)  SC% (pfx)  \
# 118      0.240      0.079        NaN        NaN      0.157        NaN
# 386      0.327        NaN        NaN        NaN      0.176        NaN
# 254      0.161      0.080        NaN        NaN      0.157        NaN
# 190      0.028      0.272        NaN        NaN      0.059        NaN
# 252      0.223      0.145        NaN        NaN      0.015        NaN
#
#      KN% (pfx)  UN% (pfx)  vFA (pfx)  vFT (pfx)  vFC (pfx)  vFS (pfx)  \
# 118        NaN        NaN       96.0       95.3        NaN        NaN
# 386        NaN        NaN       94.7       93.3        NaN        NaN
# 254        NaN        NaN       94.4        NaN       88.5        NaN
# 190        NaN        NaN       92.5        NaN       88.9        NaN
# 252        NaN        NaN       95.0        NaN       91.3        NaN
#
#      vFO (pfx)  vSI (pfx)  vSL (pfx)  vCU (pfx)  vKC (pfx)  vEP (pfx)  \
# 118        NaN        NaN       91.1       82.7        NaN        NaN
# 386        NaN        NaN       79.7        NaN        NaN        NaN
# 254        NaN        NaN       85.2       78.4        NaN        NaN
# 190        NaN       92.5       88.7       84.4        NaN        NaN
# 252        NaN        NaN       86.5       79.6        NaN        NaN
#
#      vCH (pfx)  vSC (pfx)  vKN (pfx)  FA-X (pfx)  FT-X (pfx)  FC-X (pfx)  \
# 118       88.9        NaN        NaN        -3.0        -7.4         NaN
# 386       86.6        NaN        NaN         9.3        11.2         NaN
# 254       83.9        NaN        NaN        -7.1         NaN        -0.3
# 190       85.7        NaN        NaN        -3.9         NaN         1.1
# 252       87.4        NaN        NaN        -6.9         NaN        -2.1
#
#      FS-X (pfx)  FO-X (pfx)  SI-X (pfx)  SL-X (pfx)  CU-X (pfx)  KC-X (pfx)  \
# 118         NaN         NaN         NaN         1.8         3.4         NaN
# 386         NaN         NaN         NaN        -6.3         NaN         NaN
# 254         NaN         NaN         NaN         0.7         3.5         NaN
# 190         NaN         NaN        -8.8         1.0         7.1         NaN
# 252         NaN         NaN         NaN         1.2         4.4         NaN
#
#      EP-X (pfx)  CH-X (pfx)  SC-X (pfx)  KN-X (pfx)  FA-Z (pfx)  FT-Z (pfx)  \
# 118         NaN        -7.7         NaN         NaN         9.2         6.9
# 386         NaN        11.4         NaN         NaN         7.7         4.1
# 254         NaN        -9.4         NaN         NaN         7.8         NaN
# 190         NaN        -7.8         NaN         NaN         8.8         NaN
# 252         NaN       -10.2         NaN         NaN        12.0         NaN
#
#      FC-Z (pfx)  FS-Z (pfx)  FO-Z (pfx)  SI-Z (pfx)  SL-Z (pfx)  CU-Z (pfx)  \
# 118         NaN         NaN         NaN         NaN         3.3        -2.3
# 386         NaN         NaN         NaN         NaN        -1.7         NaN
# 254         3.9         NaN         NaN         NaN         0.6        -3.6
# 190         3.8         NaN         NaN         6.0         4.7         2.3
# 252         8.2         NaN         NaN         NaN         2.1        -6.9
#
#      KC-Z (pfx)  EP-Z (pfx)  CH-Z (pfx)  SC-Z (pfx)  KN-Z (pfx)  wFA (pfx)  \
# 118         NaN         NaN         3.1         NaN         NaN       26.1
# 386         NaN         NaN         3.4         NaN         NaN       20.4
# 254         NaN         NaN         0.9         NaN         NaN       30.8
# 190         NaN         NaN         3.6         NaN         NaN        2.7
# 252         NaN         NaN         5.5         NaN         NaN       31.5
#
#      wFT (pfx)  wFC (pfx)  wFS (pfx)  wFO (pfx)  wSI (pfx)  wSL (pfx)  \
# 118       -1.5        NaN        NaN        NaN        NaN       16.6
# 386        7.2        NaN        NaN        NaN        NaN        8.6
# 254        NaN        0.2        NaN        NaN        NaN       10.3
# 190        NaN       12.2        NaN        NaN       -4.2       -2.1
# 252        NaN       -2.5        NaN        NaN        NaN        3.9
#
#      wCU (pfx)  wKC (pfx)  wEP (pfx)  wCH (pfx)  wSC (pfx)  wKN (pfx)  \
# 118        4.5        NaN        NaN       13.8        NaN        NaN
# 386        NaN        NaN        NaN        5.3        NaN        NaN
# 254       -3.6        NaN        NaN        9.7        NaN        NaN
# 190       37.3        NaN        NaN        7.4        NaN        NaN
# 252        8.9        NaN        NaN       -2.7        NaN        NaN
#
#      wFA/C (pfx)  wFT/C (pfx)  wFC/C (pfx)  wFS/C (pfx)  wFO/C (pfx)  \
# 118         1.87        -0.53          NaN          NaN          NaN
# 386         1.89         1.30          NaN          NaN          NaN
# 254         1.76          NaN         0.04          NaN          NaN
# 190         0.65          NaN         2.01          NaN          NaN
# 252         1.50          NaN       -13.15          NaN          NaN
#
#      wSI/C (pfx)  wSL/C (pfx)  wCU/C (pfx)  wKC/C (pfx)  wEP/C (pfx)  \
# 118          NaN         2.16         1.76          NaN          NaN
# 386          NaN         0.80          NaN          NaN          NaN
# 254          NaN         1.84        -1.31          NaN          NaN
# 190        -0.49        -2.57         4.67          NaN          NaN
# 252          NaN         0.51         1.80          NaN          NaN
#
#      wCH/C (pfx)  wSC/C (pfx)  wKN/C (pfx)  O-Swing% (pfx)  Z-Swing% (pfx)  \
# 118         2.75          NaN          NaN           0.368           0.663
# 386         0.91          NaN          NaN           0.375           0.619
# 254         1.77          NaN          NaN           0.362           0.661
# 190         4.28          NaN          NaN           0.383           0.599
# 252        -5.28          NaN          NaN           0.341           0.661
#
#      Swing% (pfx)  O-Contact% (pfx)  Z-Contact% (pfx)  Contact% (pfx)  \
# 118         0.517             0.539             0.799           0.707
# 386         0.500             0.541             0.793           0.701
# 254         0.519             0.519             0.772           0.689
# 190         0.489             0.435             0.848           0.682
# 252         0.509             0.557             0.790           0.716
#
#      Zone% (pfx)  Pace  RA9-WAR  BIP-Wins  LOB-Wins  FDP-Wins  Age Rng  K-BB%  \
# 118        0.507  21.3      9.5       0.4       0.1       0.5  30 - 30  0.267
# 386        0.513  20.6      7.2      -0.2      -0.1      -0.3  28 - 28  0.311
# 254        0.527  24.0      7.8       1.1      -0.6       0.4  33 - 33  0.288
# 190        0.488  23.4      8.6       1.2       0.1       1.3  31 - 31  0.295
# 252        0.525  26.3      7.4       0.9      -0.2       0.7  35 - 35  0.304
#
#      Pull%  Cent%  Oppo%  Soft%   Med%  Hard%  kwERA   TTO%  CH% (pi)  \
# 118  0.423  0.320  0.256  0.252  0.482  0.266   2.60  0.389     0.161
# 386  0.384  0.352  0.264  0.185  0.518  0.297   2.19  0.441     0.166
# 254  0.406  0.316  0.278  0.239  0.475  0.286   2.35  0.432     0.158
# 190  0.389  0.361  0.251  0.244  0.467  0.289   2.39  0.414     0.063
# 252  0.370  0.337  0.293  0.201  0.508  0.291   2.16  0.426     0.015
#
#      CS% (pi)  CU% (pi)  FA% (pi)  FC% (pi)  FS% (pi)  KN% (pi)  SB% (pi)  \
# 118       NaN     0.079     0.427       NaN       NaN       NaN       NaN
# 386       NaN       NaN     0.374       NaN       NaN       NaN       NaN
# 254       NaN     0.080     0.501     0.101       NaN       NaN       NaN
# 190       NaN       NaN     0.145     0.241       NaN       NaN       NaN
# 252       NaN     0.144     0.612     0.005       NaN       NaN       NaN
#
#      SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  vFA (pi)  \
# 118     0.095     0.239       NaN      89.6       NaN      83.2      96.7
# 386     0.131     0.329       NaN      86.8       NaN       NaN      94.9
# 254       NaN     0.160       NaN      84.3       NaN      78.7      94.7
# 190     0.279     0.271     0.001      86.0       NaN       NaN      93.0
# 252       NaN     0.224       NaN      87.8       NaN      79.8      95.4
#
#      vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  vXX (pi)  \
# 118       NaN       NaN       NaN       NaN      96.1      91.6       NaN
# 386       NaN       NaN       NaN       NaN      93.0      79.9       NaN
# 254      88.9       NaN       NaN       NaN       NaN      85.5       NaN
# 190      89.2       NaN       NaN       NaN      92.8      84.6      90.8
# 252      92.0       NaN       NaN       NaN       NaN      86.8       NaN
#
#      CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  FS-X (pi)  \
# 118       -7.4        NaN        3.9       -2.4        NaN        NaN
# 386       12.1        NaN        NaN       10.2        NaN        NaN
# 254       -8.5        NaN        4.6       -6.0        1.0        NaN
# 190       -6.9        NaN        NaN       -3.4        1.8        NaN
# 252       -9.5        NaN        5.4       -6.0       -1.3        NaN
#
#      KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  CH-Z (pi)  \
# 118        NaN        NaN       -6.9        2.4        NaN        2.9
# 386        NaN        NaN       12.3       -5.5        NaN        3.1
# 254        NaN        NaN        NaN        1.9        NaN        0.5
# 190        NaN        NaN       -8.1        7.8        0.5        3.2
# 252        NaN        NaN        NaN        2.3        NaN        4.5
#
#      CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  KN-Z (pi)  \
# 118        NaN       -2.7        9.4        NaN        NaN        NaN
# 386        NaN        NaN        7.3        NaN        NaN        NaN
# 254        NaN       -4.0        7.9        4.0        NaN        NaN
# 190        NaN        NaN        8.5        3.3        NaN        NaN
# 252        NaN       -8.0       11.2        7.0        NaN        NaN
#
#      SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  wCU (pi)  \
# 118        NaN        7.0        3.1        NaN      13.0       NaN       4.4
# 386        NaN        3.3       -1.8        NaN       4.5       NaN       NaN
# 254        NaN        NaN        0.2        NaN       9.6       NaN      -3.9
# 190        NaN        5.5        1.7        4.6       7.5       NaN       NaN
# 252        NaN        NaN        1.3        NaN      -2.8       NaN       9.0
#
#      wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  wSL (pi)  \
# 118      23.6       NaN       NaN       NaN       NaN       0.9      17.2
# 386      26.3       NaN       NaN       NaN       NaN       5.6       7.6
# 254      30.9       0.4       NaN       NaN       NaN       NaN      10.3
# 190       5.4       9.5       NaN       NaN       NaN      -6.7      37.0
# 252      31.0      -2.4       NaN       NaN       NaN       NaN       3.7
#
#      wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  wFC/C (pi)  \
# 118       NaN        2.52         NaN        1.72        1.73         NaN
# 386       NaN        0.79         NaN         NaN        2.06         NaN
# 254       NaN        1.75         NaN       -1.39        1.77        0.13
# 190       0.2        4.10         NaN         NaN        1.27        1.35
# 252       NaN       -5.46         NaN        1.82        1.48      -14.32
#
#      wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  wXX/C (pi)  \
# 118         NaN         NaN         NaN        0.30        2.25         NaN
# 386         NaN         NaN         NaN        1.24        0.67         NaN
# 254         NaN         NaN         NaN         NaN        1.85         NaN
# 190         NaN         NaN         NaN       -0.82        4.65        9.31
# 252         NaN         NaN         NaN         NaN        0.48         NaN
#
#      O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 118          0.367          0.661        0.518            0.524
# 386          0.373          0.619        0.499            0.540
# 254          0.355          0.666        0.519            0.513
# 190          0.388          0.595        0.489            0.433
# 252          0.336          0.656        0.509            0.557
#
#      Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)
# 118            0.804          0.708       0.513       21.9
# 386            0.798          0.704       0.513       20.9
# 254            0.774          0.690       0.528       24.2
# 190            0.853          0.681       0.485       23.5
# 252            0.785          0.716       0.541       27.0

# %%
features = ['Name','ERA', 'FIP', 'xFIP', 'tERA']

# %%
data[features]
# Out:
#                      Name    ERA    FIP  xFIP   tERA
# 118          Jacob deGrom   1.70   1.99  2.60   2.15
# 386            Chris Sale   2.90   2.45  2.65   2.72
# 254          Max Scherzer   2.53   2.65  3.06   2.55
# 190          Corey Kluber   2.25   2.50  2.52   2.93
# 252      Justin Verlander   2.52   2.78  3.03   2.61
# 117       Clayton Kershaw   1.69   1.80  2.28   1.91
# 246          Max Scherzer   2.51   2.90  3.28   2.75
# 375        Jose Fernandez   2.86   2.30  2.56   3.02
# 167            Chris Sale   2.11   1.98  2.31   2.15
# 378           Gerrit Cole   2.88   2.70  3.04   2.77
# 277      Noah Syndergaard   2.60   2.29  2.67   2.58
# 488        Patrick Corbin   3.15   2.47  2.61   3.17
# 250     Stephen Strasburg   2.52   2.72  3.27   2.87
# 181          Trevor Bauer   2.21   2.44  3.14   2.83
# 411         Luis Severino   2.98   3.07  3.04   3.21
# 405          Max Scherzer   2.96   3.24  3.37   3.28
# 382          Corey Kluber   2.89   3.12  3.08   3.72
# 599         Luis Severino   3.39   2.95  3.10   3.75
# 550       Carlos Carrasco   3.29   3.10  3.24   3.60
# 213            Aaron Nola   2.37   3.01  3.21   3.13
# 574            Chris Sale   3.34   3.46  3.58   3.72
# 442      Justin Verlander   3.04   3.48  3.78   3.44
# 587       Carlos Carrasco   3.38   2.94  2.90   3.41
# 487         Rick Porcello   3.15   3.40  3.89   3.62
# 481          Corey Kluber   3.14   3.26  3.50   3.58
# 508         Jose Quintana   3.20   3.56  4.03   3.77
# 343          Johnny Cueto   2.79   2.96  3.42   3.23
# 135           Blake Snell   1.89   2.95  3.16   2.94
# 649          Jimmy Nelson   3.49   3.05  3.15   3.60
# 509          Zack Greinke   3.20   3.31  3.34   3.50
# 452       Masahiro Tanaka   3.07   3.51  3.61   3.92
# 409          James Paxton   2.98   2.61  3.25   2.87
# 671            Aaron Nola   3.54   3.27  3.38   3.41
# 937          Chris Archer   4.07   3.40  3.35   3.64
# 900           David Price   3.99   3.60  3.52   4.27
# 201       Clayton Kershaw   2.31   3.07  2.84   3.05
# 358         Miles Mikolas   2.83   3.28  3.67   3.79
# 328     Madison Bumgarner   2.74   3.24  3.54   3.19
# 582      Justin Verlander   3.36   3.84  4.17   4.34
# 230            Jon Lester   2.44   3.41  3.47   3.69
# 367         Kyle Freeland   2.85   3.67  4.22   4.44
# 787        German Marquez   3.77   3.40  3.10   4.54
# 430        Mike Clevinger   3.02   3.52  3.86   3.85
# 436      Noah Syndergaard   3.03   2.80  3.29   3.33
# 558          Zack Wheeler   3.31   3.25  3.81   3.26
# 171        Kyle Hendricks   2.13   3.20  3.59   3.50
# 670          Jacob deGrom   3.53   3.50  3.23   3.57
# 972         Jose Quintana   4.15   3.68  3.73   3.92
# 701     Stephen Strasburg   3.60   2.92  3.20   3.28
# 169             Rich Hill   2.12   2.39  3.36   2.39
# ...                   ...    ...    ...   ...    ...
# 1932       Bronson Arroyo   7.35   6.99  5.81   7.33
# 1705    Carlos Villanueva   5.96   5.17  4.01   5.70
# 1984  Francisco Rodriguez   7.82   7.38  5.71   7.03
# 2082         Tim Lincecum   9.16   7.16  5.52   7.54
# 931          Javier Lopez   4.05   5.40  5.12   5.26
# 1449        Junior Guerra   5.12   6.58  5.43   7.29
# 1890       Frankie Montas   7.03   7.13  5.18   7.40
# 1931          Miguel Diaz   7.34   7.02  5.89   6.73
# 1760         Deck McGuire   6.16   6.95  5.74   7.76
# 2199         Brian Matusz  14.00  14.48  8.59  15.21
# 1738            Sam Dyson   6.09   5.63  4.96   5.65
# 1478        Logan Verrett   5.20   5.51  4.97   5.90
# 1930          Matt Albers   7.34   6.31  4.20   6.78
# 1961       Brian Duensing   7.65   6.35  6.16   6.98
# 1992         Chris Flexen   7.88   6.95  6.16   6.84
# 1270       David Holmberg   4.68   6.80  6.53   6.48
# 1605         Eddie Butler   5.62   6.14  5.02   6.50
# 1707         Kevin Jepsen   5.98   6.15  5.39   7.05
# 1782          Matt Albers   6.31   5.80  5.24   5.67
# 2157         Blaine Boyer  12.05   8.33  5.81   9.20
# 1390            Tony Sipp   4.95   6.19  4.98   5.78
# 1896        Andrew Heaney   7.06   9.11  4.37   9.28
# 2094      Anthony Ranaudo   9.48   8.06  6.62   7.23
# 1980       Brandon Maurer   7.76   6.58  5.73   6.41
# 2001           Jon Moscot   8.02   9.85  5.86  12.70
# 1766        Derek Holland   6.20   6.45  5.78   6.76
# 1841          Matt Harvey   6.70   6.37  5.39   6.66
# 1685       Tyrell Jenkins   5.88   6.86  5.93   7.19
# 1869       Tom Wilhelmsen   6.80   6.38  5.24   6.06
# 1570           Casey Fien   5.49   6.43  4.37   6.79
# 2140       Dillon Overton  11.47   9.15  6.36   8.95
# 2156        Xavier Cedeno  12.00  20.16  8.94  21.39
# 2189          J.J. Hoover  13.50   9.90  6.22  10.66
# 1651          Steve Geltz   5.74   7.91  5.42   8.01
# 1866          Chris Smith   6.79   7.02  5.97   7.07
# 2023         Erik Johnson   8.33   8.67  5.09   8.83
# 1679        James Shields   5.85   6.01  5.21   6.31
# 1687    Brett Oberholtzer   5.89   6.22  4.90   6.52
# 1694         Mike Pelfrey   5.93   6.35  5.63   6.00
# 2089        Alfredo Simon   9.36   7.14  5.71   7.28
# 1944         Jered Weaver   7.44   8.12  5.56   8.59
# 1938         Amir Garrett   7.39   7.39  5.20   7.70
# 1986        Chris Tillman   7.84   6.93  5.87   7.59
# 1763          Chris Young   6.19   6.62  4.98   6.50
# 1927         Shawn Kelley   7.27   8.62  6.04   7.83
# 1798           Chris Beck   6.40   6.84  5.88   7.19
# 1293           Josh Osich   4.71   6.09  4.78   5.52
# 1966          Dylan Covey   7.71   7.20  5.54   7.17
# 1369        Jarlin Garcia   4.91   6.37  5.17   6.43
# 1755          Josh Tomlin   6.14   7.16  5.28   8.08
#
# [2263 rows x 5 columns]

# %%
name = data.groupby(["Name"])

# %%
Max_2016_2018 = name.get_group('Max Scherzer')

# %%
CC_2016_2018
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-934c0ab675ca> in <module>
# ----> 1 CC_2016_2018
#
# NameError: name 'CC_2016_2018' is not defined

# %%
CC_2017_2018.columns

# %%
Max_2016_2018 = name.get_group('Max Scherzer')

# %%
Justin_2016_2018 = name.get_group('Justin Verlander')

# %%
Justin_2016_2018.head()
# Out:
#      Season              Name    Team   Age     W    L   ERA  WAR     G    GS  \
# 252  2018.0  Justin Verlander  Astros  35.0  16.0  9.0  2.52  6.7  34.0  34.0
# 442  2016.0  Justin Verlander  Tigers  33.0  16.0  9.0  3.04  5.3  34.0  34.0
# 582  2017.0  Justin Verlander   - - -  34.0  15.0  8.0  3.36  4.3  33.0  33.0
#
#       CG  ShO   SV   BS     IP    TBF      H     R    ER    HR    BB  IBB  \
# 252  1.0  1.0  0.0  0.0  214.0  833.0  156.0  63.0  60.0  28.0  37.0  0.0
# 442  2.0  0.0  0.0  0.0  227.2  903.0  171.0  81.0  77.0  30.0  57.0  1.0
# 582  0.0  0.0  0.0  0.0  206.0  849.0  170.0  80.0  77.0  27.0  72.0  4.0
#
#      HBP   WP   BK     SO     GB     FB     LD  IFFB   Balls  Strikes  \
# 252  8.0  5.0  2.0  290.0  143.0  253.0   96.0  37.0  1063.0   2364.0
# 442  8.0  6.0  0.0  254.0  194.0  275.0  107.0  31.0  1213.0   2455.0
# 582  4.0  5.0  0.0  219.0  184.0  235.0  131.0  23.0  1218.0   2313.0
#
#      Pitches     RS   IFH   BU  BUH    K/9  BB/9  K/BB   H/9  HR/9    AVG  \
# 252   3427.0  101.0  18.0  6.0  4.0  12.20  1.56  7.84  6.56  1.18  0.198
# 442   3668.0  110.0  12.0  8.0  0.0  10.04  2.25  4.46  6.76  1.19  0.204
# 582   3531.0  123.0   7.0  4.0  2.0   9.57  3.15  3.04  7.43  1.18  0.220
#
#      WHIP  BABIP   LOB%   FIP  GB/FB    LD%    GB%  IFFB%  HR/FB   IFH%  \
# 252  0.90  0.272  0.853  2.78   0.57  0.195  0.291  0.146  0.111  0.126
# 442  1.00  0.255  0.799  3.48   0.71  0.186  0.337  0.113  0.109  0.062
# 582  1.17  0.271  0.797  3.84   0.78  0.238  0.335  0.098  0.115  0.038
#
#       BUH%  Starting  Start-IP  Relieving  Relief-IP   RAR Dollars  tERA  \
# 252  0.667      60.4     214.0        NaN        NaN  60.4   $53.5  2.61
# 442  0.000      49.6     227.2        NaN        NaN  49.6   $42.4  3.44
# 582  0.500      41.4     206.0        NaN        NaN  41.4   $34.3  4.34
#
#      xFIP   WPA   -WPA   +WPA   RE24   REW   pLI  inLI  gmLI  exLI  Pulls  \
# 252  3.03  4.70 -11.73  16.43  40.31  4.16  0.99  1.02  0.87  1.28   33.0
# 442  3.78  3.95 -12.97  16.92  38.26  3.86  0.96  0.97  0.87  1.13   32.0
# 582  4.17  3.21 -12.53  15.75  31.27  3.04  0.98  0.96  0.88  1.28   33.0
#
#      WPA/LI  Clutch    FB%   FBv    SL%   SLv    CT%   CTv    CB%   CBv  \
# 252    3.56    1.21  0.613  95.1  0.222  86.5  0.006  91.2  0.144  79.6
# 442    2.64    1.46  0.573  93.5  0.183  88.0    NaN   NaN  0.159  78.7
# 582    2.18    1.11  0.582  95.2  0.216  88.2  0.002  91.7  0.159  80.5
#
#        CH%   CHv  SF%  SFv  KN%  KNv    XX%  PO%   wFB   wSL  wCT  wCB  wCH  \
# 252  0.015  87.4  NaN  NaN  NaN  NaN    NaN  NaN  30.2   3.9 -2.6  8.6 -2.8
# 442  0.085  85.3  NaN  NaN  NaN  NaN  0.001  NaN  12.2  18.1  NaN  9.2 -5.2
# 582  0.041  87.5  NaN  NaN  NaN  NaN  0.004  NaN  33.5  -0.5  0.4 -1.6 -3.9
#
#      wSF  wKN  wFB/C  wSL/C  wCT/C  wCB/C  wCH/C  wSF/C  wKN/C  O-Swing%  \
# 252  NaN  NaN   1.44   0.51 -13.18   1.73  -5.41    NaN    NaN     0.346
# 442  NaN  NaN   0.58   2.71    NaN   1.58  -1.68    NaN    NaN     0.343
# 582  NaN  NaN   1.63  -0.06   6.37  -0.29  -2.75    NaN    NaN     0.319
#
#      Z-Swing%  Swing%  O-Contact%  Z-Contact%  Contact%  Zone%  F-Strike%  \
# 252     0.688   0.509       0.575       0.794     0.716  0.477      0.689
# 442     0.696   0.500       0.647       0.828     0.759  0.445      0.642
# 582     0.703   0.491       0.653       0.854     0.782  0.448      0.616
#
#      SwStr%  HLD   SD   MD  ERA-  FIP-  xFIP-     K%    BB%  SIERA  RS/9  \
# 252   0.145  0.0  0.0  0.0  62.0  67.0   72.0  0.348  0.044   2.63  4.25
# 442   0.120  0.0  0.0  0.0  72.0  81.0   89.0  0.281  0.063   3.42  4.35
# 582   0.107  0.0  0.0  0.0  77.0  87.0   95.0  0.258  0.085   4.05  5.37
#
#       E-F  FA% (pfx)  FT% (pfx)  FC% (pfx)  FS% (pfx)  FO% (pfx)  SI% (pfx)  \
# 252 -0.26      0.612        NaN      0.006        NaN        NaN        NaN
# 442 -0.44      0.538        NaN        NaN        NaN        NaN        NaN
# 582 -0.48      0.568      0.008      0.008        NaN        NaN        NaN
#
#      SL% (pfx)  CU% (pfx)  KC% (pfx)  EP% (pfx)  CH% (pfx)  SC% (pfx)  \
# 252      0.223      0.145        NaN        NaN      0.015        NaN
# 442      0.181      0.158        NaN        NaN      0.124        NaN
# 582      0.217      0.162        NaN        NaN      0.038        NaN
#
#      KN% (pfx)  UN% (pfx)  vFA (pfx)  vFT (pfx)  vFC (pfx)  vFS (pfx)  \
# 252        NaN        NaN       95.0        NaN       91.3        NaN
# 442        NaN        NaN       93.7        NaN        NaN        NaN
# 582        NaN        NaN       95.3       94.9       93.2        NaN
#
#      vFO (pfx)  vSI (pfx)  vSL (pfx)  vCU (pfx)  vKC (pfx)  vEP (pfx)  \
# 252        NaN        NaN       86.5       79.6        NaN        NaN
# 442        NaN        NaN       87.9       78.7        NaN        NaN
# 582        NaN        NaN       88.2       80.5        NaN        NaN
#
#      vCH (pfx)  vSC (pfx)  vKN (pfx)  FA-X (pfx)  FT-X (pfx)  FC-X (pfx)  \
# 252       87.4        NaN        NaN        -6.9         NaN        -2.1
# 442       86.9        NaN        NaN        -7.6         NaN         NaN
# 582       87.7        NaN        NaN        -8.4       -11.8        -2.8
#
#      FS-X (pfx)  FO-X (pfx)  SI-X (pfx)  SL-X (pfx)  CU-X (pfx)  KC-X (pfx)  \
# 252         NaN         NaN         NaN         1.2         4.4         NaN
# 442         NaN         NaN         NaN         0.7         5.9         NaN
# 582         NaN         NaN         NaN        -0.3         4.2         NaN
#
#      EP-X (pfx)  CH-X (pfx)  SC-X (pfx)  KN-X (pfx)  FA-Z (pfx)  FT-Z (pfx)  \
# 252         NaN       -10.2         NaN         NaN        12.0         NaN
# 442         NaN        -9.4         NaN         NaN        10.1         NaN
# 582         NaN       -10.2         NaN         NaN        10.1         6.9
#
#      FC-Z (pfx)  FS-Z (pfx)  FO-Z (pfx)  SI-Z (pfx)  SL-Z (pfx)  CU-Z (pfx)  \
# 252         8.2         NaN         NaN         NaN         2.1        -6.9
# 442         NaN         NaN         NaN         NaN         5.0        -6.3
# 582         8.6         NaN         NaN         NaN         4.0        -5.1
#
#      KC-Z (pfx)  EP-Z (pfx)  CH-Z (pfx)  SC-Z (pfx)  KN-Z (pfx)  wFA (pfx)  \
# 252         NaN         NaN         5.5         NaN         NaN       31.5
# 442         NaN         NaN         6.3         NaN         NaN       14.8
# 582         NaN         NaN         4.7         NaN         NaN       33.2
#
#      wFT (pfx)  wFC (pfx)  wFS (pfx)  wFO (pfx)  wSI (pfx)  wSL (pfx)  \
# 252        NaN       -2.5        NaN        NaN        NaN        3.9
# 442        NaN        NaN        NaN        NaN        NaN       18.6
# 582       -0.1        1.5        NaN        NaN        NaN        0.3
#
#      wCU (pfx)  wKC (pfx)  wEP (pfx)  wCH (pfx)  wSC (pfx)  wKN (pfx)  \
# 252        8.9        NaN        NaN       -2.7        NaN        NaN
# 442        8.4        NaN        NaN       -6.6        NaN        NaN
# 582       -2.2        NaN        NaN       -2.9        NaN        NaN
#
#      wFA/C (pfx)  wFT/C (pfx)  wFC/C (pfx)  wFS/C (pfx)  wFO/C (pfx)  \
# 252         1.50          NaN       -13.15          NaN          NaN
# 442         0.75          NaN          NaN          NaN          NaN
# 582         1.66        -0.36         5.56          NaN          NaN
#
#      wSI/C (pfx)  wSL/C (pfx)  wCU/C (pfx)  wKC/C (pfx)  wEP/C (pfx)  \
# 252          NaN         0.51         1.80          NaN          NaN
# 442          NaN         2.81         1.46          NaN          NaN
# 582          NaN         0.04        -0.39          NaN          NaN
#
#      wCH/C (pfx)  wSC/C (pfx)  wKN/C (pfx)  O-Swing% (pfx)  Z-Swing% (pfx)  \
# 252        -5.28          NaN          NaN           0.341           0.661
# 442        -1.45          NaN          NaN           0.349           0.660
# 582        -2.16          NaN          NaN           0.318           0.656
#
#      Swing% (pfx)  O-Contact% (pfx)  Z-Contact% (pfx)  Contact% (pfx)  \
# 252         0.509             0.557             0.790           0.716
# 442         0.500             0.639             0.825           0.758
# 582         0.491             0.621             0.858           0.783
#
#      Zone% (pfx)  Pace  RA9-WAR  BIP-Wins  LOB-Wins  FDP-Wins  Age Rng  K-BB%  \
# 252        0.525  26.3      7.4       0.9      -0.2       0.7  35 - 35  0.304
# 442        0.486  24.3      6.7       2.1      -0.7       1.3  33 - 33  0.218
# 582        0.512  25.7      6.0       1.2       0.5       1.7  34 - 34  0.173
#
#      Pull%  Cent%  Oppo%  Soft%   Med%  Hard%  kwERA   TTO%  CH% (pi)  \
# 252  0.370  0.337  0.293  0.201  0.508  0.291   2.16  0.426     0.015
# 442  0.396  0.343  0.262  0.197  0.514  0.289   3.13  0.378     0.085
# 582  0.374  0.381  0.246  0.175  0.480  0.345   3.85  0.375     0.040
#
#      CS% (pi)  CU% (pi)  FA% (pi)  FC% (pi)  FS% (pi)  KN% (pi)  SB% (pi)  \
# 252       NaN     0.144     0.612     0.005       NaN       NaN       NaN
# 442       NaN     0.160     0.573     0.012       NaN       NaN       NaN
# 582       NaN     0.159     0.582       NaN       NaN       NaN       NaN
#
#      SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  vFA (pi)  \
# 252       NaN     0.224       NaN      87.8       NaN      79.8      95.4
# 442       NaN     0.171       NaN      86.1       NaN      79.4      94.3
# 582       NaN     0.218       0.0      87.8       NaN      80.7      95.5
#
#      vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  vXX (pi)  \
# 252      92.0       NaN       NaN       NaN       NaN      86.8       NaN
# 442      89.3       NaN       NaN       NaN       NaN      88.6       NaN
# 582       NaN       NaN       NaN       NaN       NaN      88.5      96.0
#
#      CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  FS-X (pi)  \
# 252       -9.5        NaN        5.4       -6.0       -1.3        NaN
# 442      -10.2        NaN        6.0       -7.5        1.3        NaN
# 582       -9.2        NaN        4.7       -7.9        NaN        NaN
#
#      KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  CH-Z (pi)  \
# 252        NaN        NaN        NaN        2.3        NaN        4.5
# 442        NaN        NaN        NaN        0.7        NaN        4.3
# 582        NaN        NaN        NaN        0.4        2.1        4.6
#
#      CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  KN-Z (pi)  \
# 252        NaN       -8.0       11.2        7.0        NaN        NaN
# 442        NaN       -6.2       10.2        5.7        NaN        NaN
# 582        NaN       -5.5        9.9        NaN        NaN        NaN
#
#      SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  wCU (pi)  \
# 252        NaN        NaN        1.3        NaN      -2.8       NaN       9.0
# 442        NaN        NaN        5.2        NaN      -5.0       NaN       9.1
# 582        NaN        NaN        3.7        2.4      -3.5       NaN      -1.6
#
#      wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  wSL (pi)  \
# 252      31.0      -2.4       NaN       NaN       NaN       NaN       3.7
# 442      12.5       3.5       NaN       NaN       NaN       NaN      15.2
# 582      34.2       NaN       NaN       NaN       NaN       NaN       0.0
#
#      wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  wFC/C (pi)  \
# 252       NaN       -5.46         NaN        1.82        1.48      -14.32
# 442       NaN       -1.60         NaN        1.56        0.60        7.67
# 582       0.1       -2.48         NaN       -0.28        1.67         NaN
#
#      wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  wXX/C (pi)  \
# 252         NaN         NaN         NaN         NaN        0.48         NaN
# 442         NaN         NaN         NaN         NaN        2.43         NaN
# 582         NaN         NaN         NaN         NaN        0.00       14.35
#
#      O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 252          0.336          0.656        0.509            0.557
# 442          0.356          0.649        0.500            0.638
# 582          0.315          0.656        0.491            0.624
#
#      Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)
# 252            0.785          0.716       0.541       27.0
# 442            0.827          0.758       0.492       26.4
# 582            0.855          0.783       0.517       26.9

# %%
Max_2016_2018
# Out:
#      Season          Name       Team   Age     W    L   ERA  WAR     G    GS  \
# 254  2018.0  Max Scherzer  Nationals  33.0  18.0  7.0  2.53  7.4  33.0  33.0
# 246  2017.0  Max Scherzer  Nationals  32.0  16.0  6.0  2.51  6.3  31.0  31.0
# 405  2016.0  Max Scherzer  Nationals  31.0  20.0  7.0  2.96  5.6  34.0  34.0
#
#       CG  ShO   SV   BS     IP    TBF      H     R    ER    HR    BB  IBB  \
# 254  2.0  1.0  0.0  0.0  220.2  866.0  150.0  66.0  62.0  23.0  51.0  4.0
# 246  2.0  0.0  0.0  0.0  200.2  780.0  126.0  62.0  56.0  22.0  55.0  2.0
# 405  1.0  0.0  0.0  0.0  228.1  902.0  165.0  77.0  75.0  31.0  56.0  2.0
#
#       HBP   WP   BK     SO     GB     FB     LD  IFFB   Balls  Strikes  \
# 254  12.0  4.0  1.0  300.0  170.0  236.0   90.0  38.0  1087.0   2406.0
# 246  11.0  4.0  0.0  268.0  160.0  204.0   74.0  24.0   997.0   2114.0
# 405   6.0  2.0  1.0  284.0  179.0  260.0  104.0  34.0  1145.0   2418.0
#
#      Pitches     RS   IFH    BU  BUH    K/9  BB/9  K/BB   H/9  HR/9    AVG  \
# 254   3493.0  139.0  10.0   7.0  1.0  12.24  2.08  5.88  6.12  0.94  0.187
# 246   3111.0  136.0   9.0   8.0  1.0  12.02  2.47  4.87  5.65  0.99  0.176
# 405   3563.0  136.0   6.0  12.0  0.0  11.19  2.21  5.07  6.50  1.22  0.196
#
#      WHIP  BABIP   LOB%   FIP  GB/FB    LD%    GB%  IFFB%  HR/FB   IFH%  \
# 254  0.91  0.265  0.813  2.65   0.72  0.181  0.343  0.161  0.097  0.059
# 246  0.90  0.245  0.807  2.90   0.78  0.169  0.365  0.118  0.108  0.056
# 405  0.97  0.255  0.817  3.24   0.69  0.192  0.330  0.131  0.119  0.034
#
#       BUH%  Starting  Start-IP  Relieving  Relief-IP   RAR Dollars  tERA  \
# 254  0.143      64.1     220.2        NaN        NaN  64.1   $58.8  2.55
# 246  0.125      58.2     200.2        NaN        NaN  58.2   $50.7  2.75
# 405  0.000      51.4     228.1        NaN        NaN  51.4   $44.8  3.28
#
#      xFIP   WPA   -WPA   +WPA   RE24   REW   pLI  inLI  gmLI  exLI  Pulls  \
# 254  3.06  4.84 -10.86  15.70  42.84  4.42  0.91  0.93  0.88  0.92   31.0
# 246  3.28  4.47 -10.65  15.12  45.43  4.62  0.99  1.00  0.87  1.09   29.0
# 405  3.37  4.23 -11.79  16.02  37.52  3.91  0.90  0.92  0.88  0.84   33.0
#
#      WPA/LI  Clutch    FB%   FBv    SL%   SLv    CT%   CTv    CB%   CBv  \
# 254    4.74    0.58  0.503  94.4  0.164  85.2  0.099  88.6  0.077  78.4
# 246    4.18    0.35  0.487  94.1  0.289  86.2    NaN   NaN  0.083  77.4
# 405    4.21    0.49  0.554  94.3  0.222  86.2  0.023  88.9  0.081  77.9
#
#        CH%   CHv  SF%  SFv  KN%  KNv    XX%  PO%   wFB   wSL  wCT  wCB  wCH  \
# 254  0.157  84.0  NaN  NaN  NaN  NaN  0.003  NaN  30.2  10.7 -1.4 -3.4  9.6
# 246  0.141  84.7  NaN  NaN  NaN  NaN  0.002  NaN   9.8  30.3  NaN  1.3  9.0
# 405  0.121  85.3  NaN  NaN  NaN  NaN  0.002  NaN  24.1  18.4  2.1 -0.7 -4.6
#
#      wSF  wKN  wFB/C  wSL/C  wCT/C  wCB/C  wCH/C  wSF/C  wKN/C  O-Swing%  \
# 254  NaN  NaN   1.72   1.86  -0.41  -1.27   1.75    NaN    NaN     0.358
# 246  NaN  NaN   0.65   3.37    NaN   0.49   2.04    NaN    NaN     0.350
# 405  NaN  NaN   1.22   2.34   2.53  -0.25  -1.07    NaN    NaN     0.347
#
#      Z-Swing%  Swing%  O-Contact%  Z-Contact%  Contact%  Zone%  F-Strike%  \
# 254     0.701   0.520       0.539       0.775     0.690  0.474      0.657
# 246     0.687   0.512       0.519       0.795     0.697  0.481      0.646
# 405     0.694   0.515       0.537       0.790     0.702  0.482      0.651
#
#      SwStr%  HLD   SD   MD  ERA-  FIP-  xFIP-     K%    BB%  SIERA  RS/9  \
# 254   0.162  0.0  0.0  0.0  62.0  65.0   75.0  0.346  0.059   2.71  5.67
# 246   0.155  0.0  0.0  0.0  57.0  67.0   76.0  0.344  0.071   2.98  6.10
# 405   0.153  0.0  0.0  0.0  70.0  78.0   82.0  0.315  0.062   3.05  5.36
#
#       E-F  FA% (pfx)  FT% (pfx)  FC% (pfx)  FS% (pfx)  FO% (pfx)  SI% (pfx)  \
# 254 -0.12      0.502        NaN      0.101        NaN        NaN        NaN
# 246 -0.39      0.437      0.048        NaN        NaN        NaN        NaN
# 405 -0.28      0.554        NaN      0.017        NaN        NaN        NaN
#
#      SL% (pfx)  CU% (pfx)  KC% (pfx)  EP% (pfx)  CH% (pfx)  SC% (pfx)  \
# 254      0.161      0.080        NaN        NaN      0.157        NaN
# 246      0.289      0.083        NaN        NaN      0.143        NaN
# 405      0.228      0.081        NaN        NaN      0.120        NaN
#
#      KN% (pfx)  UN% (pfx)  vFA (pfx)  vFT (pfx)  vFC (pfx)  vFS (pfx)  \
# 254        NaN        NaN       94.4        NaN       88.5        NaN
# 246        NaN        NaN       94.1       93.4        NaN        NaN
# 405        NaN        NaN       94.3        NaN       89.4        NaN
#
#      vFO (pfx)  vSI (pfx)  vSL (pfx)  vCU (pfx)  vKC (pfx)  vEP (pfx)  \
# 254        NaN        NaN       85.2       78.4        NaN        NaN
# 246        NaN        NaN       86.1       77.4        NaN        NaN
# 405        NaN        NaN       86.2       77.9        NaN        NaN
#
#      vCH (pfx)  vSC (pfx)  vKN (pfx)  FA-X (pfx)  FT-X (pfx)  FC-X (pfx)  \
# 254       83.9        NaN        NaN        -7.1         NaN        -0.3
# 246       84.7        NaN        NaN        -6.5        -8.7         NaN
# 405       85.2        NaN        NaN        -7.9         NaN        -2.2
#
#      FS-X (pfx)  FO-X (pfx)  SI-X (pfx)  SL-X (pfx)  CU-X (pfx)  KC-X (pfx)  \
# 254         NaN         NaN         NaN         0.7         3.5         NaN
# 246         NaN         NaN         NaN         1.3         4.8         NaN
# 405         NaN         NaN         NaN         0.6         3.9         NaN
#
#      EP-X (pfx)  CH-X (pfx)  SC-X (pfx)  KN-X (pfx)  FA-Z (pfx)  FT-Z (pfx)  \
# 254         NaN        -9.4         NaN         NaN         7.8         NaN
# 246         NaN        -8.7         NaN         NaN         9.9         6.1
# 405         NaN        -9.5         NaN         NaN         8.3         NaN
#
#      FC-Z (pfx)  FS-Z (pfx)  FO-Z (pfx)  SI-Z (pfx)  SL-Z (pfx)  CU-Z (pfx)  \
# 254         3.9         NaN         NaN         NaN         0.6        -3.6
# 246         NaN         NaN         NaN         NaN         2.7        -3.5
# 405         4.3         NaN         NaN         NaN         1.9        -4.0
#
#      KC-Z (pfx)  EP-Z (pfx)  CH-Z (pfx)  SC-Z (pfx)  KN-Z (pfx)  wFA (pfx)  \
# 254         NaN         NaN         0.9         NaN         NaN       30.8
# 246         NaN         NaN         2.2         NaN         NaN       11.7
# 405         NaN         NaN         1.0         NaN         NaN       24.4
#
#      wFT (pfx)  wFC (pfx)  wFS (pfx)  wFO (pfx)  wSI (pfx)  wSL (pfx)  \
# 254        NaN        0.2        NaN        NaN        NaN       10.3
# 246       -1.8        NaN        NaN        NaN        NaN       30.6
# 405        NaN        2.2        NaN        NaN        NaN       17.8
#
#      wCU (pfx)  wKC (pfx)  wEP (pfx)  wCH (pfx)  wSC (pfx)  wKN (pfx)  \
# 254       -3.6        NaN        NaN        9.7        NaN        NaN
# 246        1.3        NaN        NaN        9.1        NaN        NaN
# 405       -0.4        NaN        NaN       -4.5        NaN        NaN
#
#      wFA/C (pfx)  wFT/C (pfx)  wFC/C (pfx)  wFS/C (pfx)  wFO/C (pfx)  \
# 254         1.76          NaN         0.04          NaN          NaN
# 246         0.87        -1.19          NaN          NaN          NaN
# 405         1.24          NaN         3.48          NaN          NaN
#
#      wSI/C (pfx)  wSL/C (pfx)  wCU/C (pfx)  wKC/C (pfx)  wEP/C (pfx)  \
# 254          NaN         1.84        -1.31          NaN          NaN
# 246          NaN         3.43         0.51          NaN          NaN
# 405          NaN         2.19        -0.14          NaN          NaN
#
#      wCH/C (pfx)  wSC/C (pfx)  wKN/C (pfx)  O-Swing% (pfx)  Z-Swing% (pfx)  \
# 254         1.77          NaN          NaN           0.362           0.661
# 246         2.07          NaN          NaN           0.356           0.659
# 405        -1.05          NaN          NaN           0.351           0.660
#
#      Swing% (pfx)  O-Contact% (pfx)  Z-Contact% (pfx)  Contact% (pfx)  \
# 254         0.519             0.519             0.772           0.689
# 246         0.512             0.502             0.797           0.698
# 405         0.515             0.527             0.783           0.701
#
#      Zone% (pfx)  Pace  RA9-WAR  BIP-Wins  LOB-Wins  FDP-Wins  Age Rng  K-BB%  \
# 254        0.527  24.0      7.8       1.1      -0.6       0.4  33 - 33  0.288
# 246        0.515  24.9      7.4       2.1      -1.0       1.1  32 - 32  0.273
# 405        0.530  22.7      6.9       2.0      -0.7       1.3  31 - 31  0.253
#
#      Pull%  Cent%  Oppo%  Soft%   Med%  Hard%  kwERA   TTO%  CH% (pi)  \
# 254  0.406  0.316  0.278  0.239  0.475  0.286   2.35  0.432     0.158
# 246  0.424  0.330  0.247  0.195  0.540  0.265   2.65  0.442     0.141
# 405  0.398  0.299  0.303  0.222  0.478  0.301   2.71  0.411     0.121
#
#      CS% (pi)  CU% (pi)  FA% (pi)  FC% (pi)  FS% (pi)  KN% (pi)  SB% (pi)  \
# 254       NaN     0.080     0.501     0.101       NaN       NaN       NaN
# 246       NaN     0.084     0.486     0.042       NaN       NaN       NaN
# 405       NaN     0.081     0.554     0.037       NaN       NaN       NaN
#
#      SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  vFA (pi)  \
# 254       NaN     0.160       NaN      84.3       NaN      78.7      94.7
# 246       NaN     0.247     0.001      84.9       NaN      77.7      94.2
# 405       NaN     0.207       NaN      86.0       NaN      78.6      95.2
#
#      vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  vXX (pi)  \
# 254      88.9       NaN       NaN       NaN       NaN      85.5       NaN
# 246      88.2       NaN       NaN       NaN       NaN      85.9      88.5
# 405      89.4       NaN       NaN       NaN       NaN      86.8       NaN
#
#      CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  FS-X (pi)  \
# 254       -8.5        NaN        4.6       -6.0        1.0        NaN
# 246       -8.4        NaN        5.1       -6.5        0.8        NaN
# 405       -9.1        NaN        4.4       -7.6       -0.3        NaN
#
#      KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  CH-Z (pi)  \
# 254        NaN        NaN        NaN        1.9        NaN        0.5
# 246        NaN        NaN        NaN        1.6      -15.6        1.3
# 405        NaN        NaN        NaN        1.0        NaN        1.0
#
#      CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  KN-Z (pi)  \
# 254        NaN       -4.0        7.9        4.0        NaN        NaN
# 246        NaN       -4.4        8.5        3.3        NaN        NaN
# 405        NaN       -4.0        8.4        4.2        NaN        NaN
#
#      SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  wCU (pi)  \
# 254        NaN        NaN        0.2        NaN       9.6       NaN      -3.9
# 246        NaN        NaN        1.4       -5.4       8.6       NaN       1.4
# 405        NaN        NaN        1.7        NaN      -4.4       NaN      -0.6
#
#      wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  wSL (pi)  \
# 254      30.9       0.4       NaN       NaN       NaN       NaN      10.3
# 246       9.5       4.0       NaN       NaN       NaN       NaN      26.3
# 405      23.8       0.2       NaN       NaN       NaN       NaN      19.9
#
#      wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  wFC/C (pi)  \
# 254       NaN        1.75         NaN       -1.39        1.77        0.13
# 246       0.1        1.98         NaN        0.53        0.64        3.09
# 405       NaN       -1.03         NaN       -0.19        1.21        0.14
#
#      wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  wXX/C (pi)  \
# 254         NaN         NaN         NaN         NaN        1.85         NaN
# 246         NaN         NaN         NaN         NaN        3.46        4.27
# 405         NaN         NaN         NaN         NaN        2.70         NaN
#
#      O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 254          0.355          0.666        0.519            0.513
# 246          0.366          0.653        0.512            0.496
# 405          0.349          0.662        0.514            0.531
#
#      Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)
# 254            0.774          0.690       0.528       24.2
# 246            0.807          0.697       0.506       25.1
# 405            0.782          0.701       0.527       22.9

# %%
CC_2016_2018
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-934c0ab675ca> in <module>
# ----> 1 CC_2016_2018
#
# NameError: name 'CC_2016_2018' is not defined

# %%
(4.14 + 4.35 + 4.18)/3
# Out:
# 4.223333333333333

# %%
4.22 + (20 + 55 - 137)/160
# Out:
# 3.8324999999999996

# %%
def predict_ERA(C,a,b,k,i):
    era = C + (a + b - k)/i
    return era

# %%
predict_ERA(C= 4.22, a = 20, b = 55, k= 137, i= 160)
# Out:
# 3.8324999999999996

# %%
Max_2016_2018
# Out:
#      Season          Name       Team   Age     W    L   ERA  WAR     G    GS  \
# 254  2018.0  Max Scherzer  Nationals  33.0  18.0  7.0  2.53  7.4  33.0  33.0
# 246  2017.0  Max Scherzer  Nationals  32.0  16.0  6.0  2.51  6.3  31.0  31.0
# 405  2016.0  Max Scherzer  Nationals  31.0  20.0  7.0  2.96  5.6  34.0  34.0
#
#       CG  ShO   SV   BS     IP    TBF      H     R    ER    HR    BB  IBB  \
# 254  2.0  1.0  0.0  0.0  220.2  866.0  150.0  66.0  62.0  23.0  51.0  4.0
# 246  2.0  0.0  0.0  0.0  200.2  780.0  126.0  62.0  56.0  22.0  55.0  2.0
# 405  1.0  0.0  0.0  0.0  228.1  902.0  165.0  77.0  75.0  31.0  56.0  2.0
#
#       HBP   WP   BK     SO     GB     FB     LD  IFFB   Balls  Strikes  \
# 254  12.0  4.0  1.0  300.0  170.0  236.0   90.0  38.0  1087.0   2406.0
# 246  11.0  4.0  0.0  268.0  160.0  204.0   74.0  24.0   997.0   2114.0
# 405   6.0  2.0  1.0  284.0  179.0  260.0  104.0  34.0  1145.0   2418.0
#
#      Pitches     RS   IFH    BU  BUH    K/9  BB/9  K/BB   H/9  HR/9    AVG  \
# 254   3493.0  139.0  10.0   7.0  1.0  12.24  2.08  5.88  6.12  0.94  0.187
# 246   3111.0  136.0   9.0   8.0  1.0  12.02  2.47  4.87  5.65  0.99  0.176
# 405   3563.0  136.0   6.0  12.0  0.0  11.19  2.21  5.07  6.50  1.22  0.196
#
#      WHIP  BABIP   LOB%   FIP  GB/FB    LD%    GB%  IFFB%  HR/FB   IFH%  \
# 254  0.91  0.265  0.813  2.65   0.72  0.181  0.343  0.161  0.097  0.059
# 246  0.90  0.245  0.807  2.90   0.78  0.169  0.365  0.118  0.108  0.056
# 405  0.97  0.255  0.817  3.24   0.69  0.192  0.330  0.131  0.119  0.034
#
#       BUH%  Starting  Start-IP  Relieving  Relief-IP   RAR Dollars  tERA  \
# 254  0.143      64.1     220.2        NaN        NaN  64.1   $58.8  2.55
# 246  0.125      58.2     200.2        NaN        NaN  58.2   $50.7  2.75
# 405  0.000      51.4     228.1        NaN        NaN  51.4   $44.8  3.28
#
#      xFIP   WPA   -WPA   +WPA   RE24   REW   pLI  inLI  gmLI  exLI  Pulls  \
# 254  3.06  4.84 -10.86  15.70  42.84  4.42  0.91  0.93  0.88  0.92   31.0
# 246  3.28  4.47 -10.65  15.12  45.43  4.62  0.99  1.00  0.87  1.09   29.0
# 405  3.37  4.23 -11.79  16.02  37.52  3.91  0.90  0.92  0.88  0.84   33.0
#
#      WPA/LI  Clutch    FB%   FBv    SL%   SLv    CT%   CTv    CB%   CBv  \
# 254    4.74    0.58  0.503  94.4  0.164  85.2  0.099  88.6  0.077  78.4
# 246    4.18    0.35  0.487  94.1  0.289  86.2    NaN   NaN  0.083  77.4
# 405    4.21    0.49  0.554  94.3  0.222  86.2  0.023  88.9  0.081  77.9
#
#        CH%   CHv  SF%  SFv  KN%  KNv    XX%  PO%   wFB   wSL  wCT  wCB  wCH  \
# 254  0.157  84.0  NaN  NaN  NaN  NaN  0.003  NaN  30.2  10.7 -1.4 -3.4  9.6
# 246  0.141  84.7  NaN  NaN  NaN  NaN  0.002  NaN   9.8  30.3  NaN  1.3  9.0
# 405  0.121  85.3  NaN  NaN  NaN  NaN  0.002  NaN  24.1  18.4  2.1 -0.7 -4.6
#
#      wSF  wKN  wFB/C  wSL/C  wCT/C  wCB/C  wCH/C  wSF/C  wKN/C  O-Swing%  \
# 254  NaN  NaN   1.72   1.86  -0.41  -1.27   1.75    NaN    NaN     0.358
# 246  NaN  NaN   0.65   3.37    NaN   0.49   2.04    NaN    NaN     0.350
# 405  NaN  NaN   1.22   2.34   2.53  -0.25  -1.07    NaN    NaN     0.347
#
#      Z-Swing%  Swing%  O-Contact%  Z-Contact%  Contact%  Zone%  F-Strike%  \
# 254     0.701   0.520       0.539       0.775     0.690  0.474      0.657
# 246     0.687   0.512       0.519       0.795     0.697  0.481      0.646
# 405     0.694   0.515       0.537       0.790     0.702  0.482      0.651
#
#      SwStr%  HLD   SD   MD  ERA-  FIP-  xFIP-     K%    BB%  SIERA  RS/9  \
# 254   0.162  0.0  0.0  0.0  62.0  65.0   75.0  0.346  0.059   2.71  5.67
# 246   0.155  0.0  0.0  0.0  57.0  67.0   76.0  0.344  0.071   2.98  6.10
# 405   0.153  0.0  0.0  0.0  70.0  78.0   82.0  0.315  0.062   3.05  5.36
#
#       E-F  FA% (pfx)  FT% (pfx)  FC% (pfx)  FS% (pfx)  FO% (pfx)  SI% (pfx)  \
# 254 -0.12      0.502        NaN      0.101        NaN        NaN        NaN
# 246 -0.39      0.437      0.048        NaN        NaN        NaN        NaN
# 405 -0.28      0.554        NaN      0.017        NaN        NaN        NaN
#
#      SL% (pfx)  CU% (pfx)  KC% (pfx)  EP% (pfx)  CH% (pfx)  SC% (pfx)  \
# 254      0.161      0.080        NaN        NaN      0.157        NaN
# 246      0.289      0.083        NaN        NaN      0.143        NaN
# 405      0.228      0.081        NaN        NaN      0.120        NaN
#
#      KN% (pfx)  UN% (pfx)  vFA (pfx)  vFT (pfx)  vFC (pfx)  vFS (pfx)  \
# 254        NaN        NaN       94.4        NaN       88.5        NaN
# 246        NaN        NaN       94.1       93.4        NaN        NaN
# 405        NaN        NaN       94.3        NaN       89.4        NaN
#
#      vFO (pfx)  vSI (pfx)  vSL (pfx)  vCU (pfx)  vKC (pfx)  vEP (pfx)  \
# 254        NaN        NaN       85.2       78.4        NaN        NaN
# 246        NaN        NaN       86.1       77.4        NaN        NaN
# 405        NaN        NaN       86.2       77.9        NaN        NaN
#
#      vCH (pfx)  vSC (pfx)  vKN (pfx)  FA-X (pfx)  FT-X (pfx)  FC-X (pfx)  \
# 254       83.9        NaN        NaN        -7.1         NaN        -0.3
# 246       84.7        NaN        NaN        -6.5        -8.7         NaN
# 405       85.2        NaN        NaN        -7.9         NaN        -2.2
#
#      FS-X (pfx)  FO-X (pfx)  SI-X (pfx)  SL-X (pfx)  CU-X (pfx)  KC-X (pfx)  \
# 254         NaN         NaN         NaN         0.7         3.5         NaN
# 246         NaN         NaN         NaN         1.3         4.8         NaN
# 405         NaN         NaN         NaN         0.6         3.9         NaN
#
#      EP-X (pfx)  CH-X (pfx)  SC-X (pfx)  KN-X (pfx)  FA-Z (pfx)  FT-Z (pfx)  \
# 254         NaN        -9.4         NaN         NaN         7.8         NaN
# 246         NaN        -8.7         NaN         NaN         9.9         6.1
# 405         NaN        -9.5         NaN         NaN         8.3         NaN
#
#      FC-Z (pfx)  FS-Z (pfx)  FO-Z (pfx)  SI-Z (pfx)  SL-Z (pfx)  CU-Z (pfx)  \
# 254         3.9         NaN         NaN         NaN         0.6        -3.6
# 246         NaN         NaN         NaN         NaN         2.7        -3.5
# 405         4.3         NaN         NaN         NaN         1.9        -4.0
#
#      KC-Z (pfx)  EP-Z (pfx)  CH-Z (pfx)  SC-Z (pfx)  KN-Z (pfx)  wFA (pfx)  \
# 254         NaN         NaN         0.9         NaN         NaN       30.8
# 246         NaN         NaN         2.2         NaN         NaN       11.7
# 405         NaN         NaN         1.0         NaN         NaN       24.4
#
#      wFT (pfx)  wFC (pfx)  wFS (pfx)  wFO (pfx)  wSI (pfx)  wSL (pfx)  \
# 254        NaN        0.2        NaN        NaN        NaN       10.3
# 246       -1.8        NaN        NaN        NaN        NaN       30.6
# 405        NaN        2.2        NaN        NaN        NaN       17.8
#
#      wCU (pfx)  wKC (pfx)  wEP (pfx)  wCH (pfx)  wSC (pfx)  wKN (pfx)  \
# 254       -3.6        NaN        NaN        9.7        NaN        NaN
# 246        1.3        NaN        NaN        9.1        NaN        NaN
# 405       -0.4        NaN        NaN       -4.5        NaN        NaN
#
#      wFA/C (pfx)  wFT/C (pfx)  wFC/C (pfx)  wFS/C (pfx)  wFO/C (pfx)  \
# 254         1.76          NaN         0.04          NaN          NaN
# 246         0.87        -1.19          NaN          NaN          NaN
# 405         1.24          NaN         3.48          NaN          NaN
#
#      wSI/C (pfx)  wSL/C (pfx)  wCU/C (pfx)  wKC/C (pfx)  wEP/C (pfx)  \
# 254          NaN         1.84        -1.31          NaN          NaN
# 246          NaN         3.43         0.51          NaN          NaN
# 405          NaN         2.19        -0.14          NaN          NaN
#
#      wCH/C (pfx)  wSC/C (pfx)  wKN/C (pfx)  O-Swing% (pfx)  Z-Swing% (pfx)  \
# 254         1.77          NaN          NaN           0.362           0.661
# 246         2.07          NaN          NaN           0.356           0.659
# 405        -1.05          NaN          NaN           0.351           0.660
#
#      Swing% (pfx)  O-Contact% (pfx)  Z-Contact% (pfx)  Contact% (pfx)  \
# 254         0.519             0.519             0.772           0.689
# 246         0.512             0.502             0.797           0.698
# 405         0.515             0.527             0.783           0.701
#
#      Zone% (pfx)  Pace  RA9-WAR  BIP-Wins  LOB-Wins  FDP-Wins  Age Rng  K-BB%  \
# 254        0.527  24.0      7.8       1.1      -0.6       0.4  33 - 33  0.288
# 246        0.515  24.9      7.4       2.1      -1.0       1.1  32 - 32  0.273
# 405        0.530  22.7      6.9       2.0      -0.7       1.3  31 - 31  0.253
#
#      Pull%  Cent%  Oppo%  Soft%   Med%  Hard%  kwERA   TTO%  CH% (pi)  \
# 254  0.406  0.316  0.278  0.239  0.475  0.286   2.35  0.432     0.158
# 246  0.424  0.330  0.247  0.195  0.540  0.265   2.65  0.442     0.141
# 405  0.398  0.299  0.303  0.222  0.478  0.301   2.71  0.411     0.121
#
#      CS% (pi)  CU% (pi)  FA% (pi)  FC% (pi)  FS% (pi)  KN% (pi)  SB% (pi)  \
# 254       NaN     0.080     0.501     0.101       NaN       NaN       NaN
# 246       NaN     0.084     0.486     0.042       NaN       NaN       NaN
# 405       NaN     0.081     0.554     0.037       NaN       NaN       NaN
#
#      SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  vFA (pi)  \
# 254       NaN     0.160       NaN      84.3       NaN      78.7      94.7
# 246       NaN     0.247     0.001      84.9       NaN      77.7      94.2
# 405       NaN     0.207       NaN      86.0       NaN      78.6      95.2
#
#      vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  vXX (pi)  \
# 254      88.9       NaN       NaN       NaN       NaN      85.5       NaN
# 246      88.2       NaN       NaN       NaN       NaN      85.9      88.5
# 405      89.4       NaN       NaN       NaN       NaN      86.8       NaN
#
#      CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  FS-X (pi)  \
# 254       -8.5        NaN        4.6       -6.0        1.0        NaN
# 246       -8.4        NaN        5.1       -6.5        0.8        NaN
# 405       -9.1        NaN        4.4       -7.6       -0.3        NaN
#
#      KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  CH-Z (pi)  \
# 254        NaN        NaN        NaN        1.9        NaN        0.5
# 246        NaN        NaN        NaN        1.6      -15.6        1.3
# 405        NaN        NaN        NaN        1.0        NaN        1.0
#
#      CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  KN-Z (pi)  \
# 254        NaN       -4.0        7.9        4.0        NaN        NaN
# 246        NaN       -4.4        8.5        3.3        NaN        NaN
# 405        NaN       -4.0        8.4        4.2        NaN        NaN
#
#      SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  wCU (pi)  \
# 254        NaN        NaN        0.2        NaN       9.6       NaN      -3.9
# 246        NaN        NaN        1.4       -5.4       8.6       NaN       1.4
# 405        NaN        NaN        1.7        NaN      -4.4       NaN      -0.6
#
#      wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  wSL (pi)  \
# 254      30.9       0.4       NaN       NaN       NaN       NaN      10.3
# 246       9.5       4.0       NaN       NaN       NaN       NaN      26.3
# 405      23.8       0.2       NaN       NaN       NaN       NaN      19.9
#
#      wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  wFC/C (pi)  \
# 254       NaN        1.75         NaN       -1.39        1.77        0.13
# 246       0.1        1.98         NaN        0.53        0.64        3.09
# 405       NaN       -1.03         NaN       -0.19        1.21        0.14
#
#      wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  wXX/C (pi)  \
# 254         NaN         NaN         NaN         NaN        1.85         NaN
# 246         NaN         NaN         NaN         NaN        3.46        4.27
# 405         NaN         NaN         NaN         NaN        2.70         NaN
#
#      O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 254          0.355          0.666        0.519            0.513
# 246          0.366          0.653        0.512            0.496
# 405          0.349          0.662        0.514            0.531
#
#      Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)
# 254            0.774          0.690       0.528       24.2
# 246            0.807          0.697       0.506       25.1
# 405            0.782          0.701       0.527       22.9

# %%
predict_ERA(C=4.22, a=25, b=54,k=284, i=216.1)
# Out:
# 3.2713651087459508

# %%
Justin_2016_2018
# Out:
#      Season              Name    Team   Age     W    L   ERA  WAR     G    GS  \
# 252  2018.0  Justin Verlander  Astros  35.0  16.0  9.0  2.52  6.7  34.0  34.0
# 442  2016.0  Justin Verlander  Tigers  33.0  16.0  9.0  3.04  5.3  34.0  34.0
# 582  2017.0  Justin Verlander   - - -  34.0  15.0  8.0  3.36  4.3  33.0  33.0
#
#       CG  ShO   SV   BS     IP    TBF      H     R    ER    HR    BB  IBB  \
# 252  1.0  1.0  0.0  0.0  214.0  833.0  156.0  63.0  60.0  28.0  37.0  0.0
# 442  2.0  0.0  0.0  0.0  227.2  903.0  171.0  81.0  77.0  30.0  57.0  1.0
# 582  0.0  0.0  0.0  0.0  206.0  849.0  170.0  80.0  77.0  27.0  72.0  4.0
#
#      HBP   WP   BK     SO     GB     FB     LD  IFFB   Balls  Strikes  \
# 252  8.0  5.0  2.0  290.0  143.0  253.0   96.0  37.0  1063.0   2364.0
# 442  8.0  6.0  0.0  254.0  194.0  275.0  107.0  31.0  1213.0   2455.0
# 582  4.0  5.0  0.0  219.0  184.0  235.0  131.0  23.0  1218.0   2313.0
#
#      Pitches     RS   IFH   BU  BUH    K/9  BB/9  K/BB   H/9  HR/9    AVG  \
# 252   3427.0  101.0  18.0  6.0  4.0  12.20  1.56  7.84  6.56  1.18  0.198
# 442   3668.0  110.0  12.0  8.0  0.0  10.04  2.25  4.46  6.76  1.19  0.204
# 582   3531.0  123.0   7.0  4.0  2.0   9.57  3.15  3.04  7.43  1.18  0.220
#
#      WHIP  BABIP   LOB%   FIP  GB/FB    LD%    GB%  IFFB%  HR/FB   IFH%  \
# 252  0.90  0.272  0.853  2.78   0.57  0.195  0.291  0.146  0.111  0.126
# 442  1.00  0.255  0.799  3.48   0.71  0.186  0.337  0.113  0.109  0.062
# 582  1.17  0.271  0.797  3.84   0.78  0.238  0.335  0.098  0.115  0.038
#
#       BUH%  Starting  Start-IP  Relieving  Relief-IP   RAR Dollars  tERA  \
# 252  0.667      60.4     214.0        NaN        NaN  60.4   $53.5  2.61
# 442  0.000      49.6     227.2        NaN        NaN  49.6   $42.4  3.44
# 582  0.500      41.4     206.0        NaN        NaN  41.4   $34.3  4.34
#
#      xFIP   WPA   -WPA   +WPA   RE24   REW   pLI  inLI  gmLI  exLI  Pulls  \
# 252  3.03  4.70 -11.73  16.43  40.31  4.16  0.99  1.02  0.87  1.28   33.0
# 442  3.78  3.95 -12.97  16.92  38.26  3.86  0.96  0.97  0.87  1.13   32.0
# 582  4.17  3.21 -12.53  15.75  31.27  3.04  0.98  0.96  0.88  1.28   33.0
#
#      WPA/LI  Clutch    FB%   FBv    SL%   SLv    CT%   CTv    CB%   CBv  \
# 252    3.56    1.21  0.613  95.1  0.222  86.5  0.006  91.2  0.144  79.6
# 442    2.64    1.46  0.573  93.5  0.183  88.0    NaN   NaN  0.159  78.7
# 582    2.18    1.11  0.582  95.2  0.216  88.2  0.002  91.7  0.159  80.5
#
#        CH%   CHv  SF%  SFv  KN%  KNv    XX%  PO%   wFB   wSL  wCT  wCB  wCH  \
# 252  0.015  87.4  NaN  NaN  NaN  NaN    NaN  NaN  30.2   3.9 -2.6  8.6 -2.8
# 442  0.085  85.3  NaN  NaN  NaN  NaN  0.001  NaN  12.2  18.1  NaN  9.2 -5.2
# 582  0.041  87.5  NaN  NaN  NaN  NaN  0.004  NaN  33.5  -0.5  0.4 -1.6 -3.9
#
#      wSF  wKN  wFB/C  wSL/C  wCT/C  wCB/C  wCH/C  wSF/C  wKN/C  O-Swing%  \
# 252  NaN  NaN   1.44   0.51 -13.18   1.73  -5.41    NaN    NaN     0.346
# 442  NaN  NaN   0.58   2.71    NaN   1.58  -1.68    NaN    NaN     0.343
# 582  NaN  NaN   1.63  -0.06   6.37  -0.29  -2.75    NaN    NaN     0.319
#
#      Z-Swing%  Swing%  O-Contact%  Z-Contact%  Contact%  Zone%  F-Strike%  \
# 252     0.688   0.509       0.575       0.794     0.716  0.477      0.689
# 442     0.696   0.500       0.647       0.828     0.759  0.445      0.642
# 582     0.703   0.491       0.653       0.854     0.782  0.448      0.616
#
#      SwStr%  HLD   SD   MD  ERA-  FIP-  xFIP-     K%    BB%  SIERA  RS/9  \
# 252   0.145  0.0  0.0  0.0  62.0  67.0   72.0  0.348  0.044   2.63  4.25
# 442   0.120  0.0  0.0  0.0  72.0  81.0   89.0  0.281  0.063   3.42  4.35
# 582   0.107  0.0  0.0  0.0  77.0  87.0   95.0  0.258  0.085   4.05  5.37
#
#       E-F  FA% (pfx)  FT% (pfx)  FC% (pfx)  FS% (pfx)  FO% (pfx)  SI% (pfx)  \
# 252 -0.26      0.612        NaN      0.006        NaN        NaN        NaN
# 442 -0.44      0.538        NaN        NaN        NaN        NaN        NaN
# 582 -0.48      0.568      0.008      0.008        NaN        NaN        NaN
#
#      SL% (pfx)  CU% (pfx)  KC% (pfx)  EP% (pfx)  CH% (pfx)  SC% (pfx)  \
# 252      0.223      0.145        NaN        NaN      0.015        NaN
# 442      0.181      0.158        NaN        NaN      0.124        NaN
# 582      0.217      0.162        NaN        NaN      0.038        NaN
#
#      KN% (pfx)  UN% (pfx)  vFA (pfx)  vFT (pfx)  vFC (pfx)  vFS (pfx)  \
# 252        NaN        NaN       95.0        NaN       91.3        NaN
# 442        NaN        NaN       93.7        NaN        NaN        NaN
# 582        NaN        NaN       95.3       94.9       93.2        NaN
#
#      vFO (pfx)  vSI (pfx)  vSL (pfx)  vCU (pfx)  vKC (pfx)  vEP (pfx)  \
# 252        NaN        NaN       86.5       79.6        NaN        NaN
# 442        NaN        NaN       87.9       78.7        NaN        NaN
# 582        NaN        NaN       88.2       80.5        NaN        NaN
#
#      vCH (pfx)  vSC (pfx)  vKN (pfx)  FA-X (pfx)  FT-X (pfx)  FC-X (pfx)  \
# 252       87.4        NaN        NaN        -6.9         NaN        -2.1
# 442       86.9        NaN        NaN        -7.6         NaN         NaN
# 582       87.7        NaN        NaN        -8.4       -11.8        -2.8
#
#      FS-X (pfx)  FO-X (pfx)  SI-X (pfx)  SL-X (pfx)  CU-X (pfx)  KC-X (pfx)  \
# 252         NaN         NaN         NaN         1.2         4.4         NaN
# 442         NaN         NaN         NaN         0.7         5.9         NaN
# 582         NaN         NaN         NaN        -0.3         4.2         NaN
#
#      EP-X (pfx)  CH-X (pfx)  SC-X (pfx)  KN-X (pfx)  FA-Z (pfx)  FT-Z (pfx)  \
# 252         NaN       -10.2         NaN         NaN        12.0         NaN
# 442         NaN        -9.4         NaN         NaN        10.1         NaN
# 582         NaN       -10.2         NaN         NaN        10.1         6.9
#
#      FC-Z (pfx)  FS-Z (pfx)  FO-Z (pfx)  SI-Z (pfx)  SL-Z (pfx)  CU-Z (pfx)  \
# 252         8.2         NaN         NaN         NaN         2.1        -6.9
# 442         NaN         NaN         NaN         NaN         5.0        -6.3
# 582         8.6         NaN         NaN         NaN         4.0        -5.1
#
#      KC-Z (pfx)  EP-Z (pfx)  CH-Z (pfx)  SC-Z (pfx)  KN-Z (pfx)  wFA (pfx)  \
# 252         NaN         NaN         5.5         NaN         NaN       31.5
# 442         NaN         NaN         6.3         NaN         NaN       14.8
# 582         NaN         NaN         4.7         NaN         NaN       33.2
#
#      wFT (pfx)  wFC (pfx)  wFS (pfx)  wFO (pfx)  wSI (pfx)  wSL (pfx)  \
# 252        NaN       -2.5        NaN        NaN        NaN        3.9
# 442        NaN        NaN        NaN        NaN        NaN       18.6
# 582       -0.1        1.5        NaN        NaN        NaN        0.3
#
#      wCU (pfx)  wKC (pfx)  wEP (pfx)  wCH (pfx)  wSC (pfx)  wKN (pfx)  \
# 252        8.9        NaN        NaN       -2.7        NaN        NaN
# 442        8.4        NaN        NaN       -6.6        NaN        NaN
# 582       -2.2        NaN        NaN       -2.9        NaN        NaN
#
#      wFA/C (pfx)  wFT/C (pfx)  wFC/C (pfx)  wFS/C (pfx)  wFO/C (pfx)  \
# 252         1.50          NaN       -13.15          NaN          NaN
# 442         0.75          NaN          NaN          NaN          NaN
# 582         1.66        -0.36         5.56          NaN          NaN
#
#      wSI/C (pfx)  wSL/C (pfx)  wCU/C (pfx)  wKC/C (pfx)  wEP/C (pfx)  \
# 252          NaN         0.51         1.80          NaN          NaN
# 442          NaN         2.81         1.46          NaN          NaN
# 582          NaN         0.04        -0.39          NaN          NaN
#
#      wCH/C (pfx)  wSC/C (pfx)  wKN/C (pfx)  O-Swing% (pfx)  Z-Swing% (pfx)  \
# 252        -5.28          NaN          NaN           0.341           0.661
# 442        -1.45          NaN          NaN           0.349           0.660
# 582        -2.16          NaN          NaN           0.318           0.656
#
#      Swing% (pfx)  O-Contact% (pfx)  Z-Contact% (pfx)  Contact% (pfx)  \
# 252         0.509             0.557             0.790           0.716
# 442         0.500             0.639             0.825           0.758
# 582         0.491             0.621             0.858           0.783
#
#      Zone% (pfx)  Pace  RA9-WAR  BIP-Wins  LOB-Wins  FDP-Wins  Age Rng  K-BB%  \
# 252        0.525  26.3      7.4       0.9      -0.2       0.7  35 - 35  0.304
# 442        0.486  24.3      6.7       2.1      -0.7       1.3  33 - 33  0.218
# 582        0.512  25.7      6.0       1.2       0.5       1.7  34 - 34  0.173
#
#      Pull%  Cent%  Oppo%  Soft%   Med%  Hard%  kwERA   TTO%  CH% (pi)  \
# 252  0.370  0.337  0.293  0.201  0.508  0.291   2.16  0.426     0.015
# 442  0.396  0.343  0.262  0.197  0.514  0.289   3.13  0.378     0.085
# 582  0.374  0.381  0.246  0.175  0.480  0.345   3.85  0.375     0.040
#
#      CS% (pi)  CU% (pi)  FA% (pi)  FC% (pi)  FS% (pi)  KN% (pi)  SB% (pi)  \
# 252       NaN     0.144     0.612     0.005       NaN       NaN       NaN
# 442       NaN     0.160     0.573     0.012       NaN       NaN       NaN
# 582       NaN     0.159     0.582       NaN       NaN       NaN       NaN
#
#      SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  vFA (pi)  \
# 252       NaN     0.224       NaN      87.8       NaN      79.8      95.4
# 442       NaN     0.171       NaN      86.1       NaN      79.4      94.3
# 582       NaN     0.218       0.0      87.8       NaN      80.7      95.5
#
#      vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  vXX (pi)  \
# 252      92.0       NaN       NaN       NaN       NaN      86.8       NaN
# 442      89.3       NaN       NaN       NaN       NaN      88.6       NaN
# 582       NaN       NaN       NaN       NaN       NaN      88.5      96.0
#
#      CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  FS-X (pi)  \
# 252       -9.5        NaN        5.4       -6.0       -1.3        NaN
# 442      -10.2        NaN        6.0       -7.5        1.3        NaN
# 582       -9.2        NaN        4.7       -7.9        NaN        NaN
#
#      KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  CH-Z (pi)  \
# 252        NaN        NaN        NaN        2.3        NaN        4.5
# 442        NaN        NaN        NaN        0.7        NaN        4.3
# 582        NaN        NaN        NaN        0.4        2.1        4.6
#
#      CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  KN-Z (pi)  \
# 252        NaN       -8.0       11.2        7.0        NaN        NaN
# 442        NaN       -6.2       10.2        5.7        NaN        NaN
# 582        NaN       -5.5        9.9        NaN        NaN        NaN
#
#      SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  wCU (pi)  \
# 252        NaN        NaN        1.3        NaN      -2.8       NaN       9.0
# 442        NaN        NaN        5.2        NaN      -5.0       NaN       9.1
# 582        NaN        NaN        3.7        2.4      -3.5       NaN      -1.6
#
#      wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  wSL (pi)  \
# 252      31.0      -2.4       NaN       NaN       NaN       NaN       3.7
# 442      12.5       3.5       NaN       NaN       NaN       NaN      15.2
# 582      34.2       NaN       NaN       NaN       NaN       NaN       0.0
#
#      wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  wFC/C (pi)  \
# 252       NaN       -5.46         NaN        1.82        1.48      -14.32
# 442       NaN       -1.60         NaN        1.56        0.60        7.67
# 582       0.1       -2.48         NaN       -0.28        1.67         NaN
#
#      wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  wXX/C (pi)  \
# 252         NaN         NaN         NaN         NaN        0.48         NaN
# 442         NaN         NaN         NaN         NaN        2.43         NaN
# 582         NaN         NaN         NaN         NaN        0.00       14.35
#
#      O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 252          0.336          0.656        0.509            0.557
# 442          0.356          0.649        0.500            0.638
# 582          0.315          0.656        0.491            0.624
#
#      Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)
# 252            0.785          0.716       0.541       27.0
# 442            0.827          0.758       0.492       26.4
# 582            0.855          0.783       0.517       26.9

# %%
predict_ERA(C=4.22,a=28.33, b=55.33,k=254.3, i=215.7)
# Out:
# 3.4289012517385253

# %%
features = ['Name','ER', 'IP','ERA']

# %%
sns.scatterplot(x='HR', y='R',data=Max_2016_2018)

# %%
prior = beta(a=28.33, b=55.3)

# %%
xvals = np.linspace(0,1, 216 )

# %%
yvals = prior.pdf(xvals)

# %%
plt.plot(xvals, yvals)
plt.xlabel('ERA')
plt.ylabel('Probability Density')
plt.title('Prior Distribution of ERA for Justin Verlander');

# %%
predict_ERA(C=4.22, a=25, b=54,k=284, i=216.1)
# Out:
# 3.2713651087459508

# %%
prior_Max = beta(a=25, b=54)

# %%
xvals_Max = np.linspace(0,1, 216)

# %%
yvals_Max = prior_Max.pdf(xvals_Max)

# %%
plt.plot(xvals_Max, yvals_Max)
plt.xlabel('ERA')
plt.ylabel('Probability Density')
plt.title('Prior Distribution of ERA for Max Scherzer');

# %%
predict_ERA(C= 4.22, a = 20, b = 55, k= 137, i= 160)
# Out:
# 3.8324999999999996

# %%
prior_CC = beta(a=20, b=55)

# %%
xvals_CC = np.linspace(0,1, 216)

# %%
yvals_CC = prior_CC.pdf(xvals_CC)

# %%
plt.plot(xvals_CC, yvals_CC)
plt.xlabel('ERA')
plt.ylabel('Probability Density')
plt.title('Prior Distribution of ERA for CC Sabathia');

# %%
data["FIP"].mean()
# Out:
# 4.868811312417121

# %%
def get_map(row):    
    #ER
    alpha_prior = 30
    #IP
    beta_prior = 60
    alpha_posterior = row['ER'] + alpha_prior
    beta_posterior =  row["IP"] - row['ER'] + beta_prior
    return (9 * alpha_posterior - 1) / (alpha_posterior + beta_posterior -2)

# %%
ERA_2016_2018= data[features]

# %%
ERA_2016_2018.set_index('Name', inplace=True)

# %%
get_map(ERA_2016_2018.head(1))
# Out:
# Name
# Jacob deGrom    2.091803
# dtype: float64

# %%
ERA_2016_2018['MAP'] = ERA_2016_2018.apply(get_map, axis=1)
# Out:
# /Users/orah82/anaconda3/envs/DSI/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ERA_2016_2018.sort_values('MAP', ascending=True).head()
# Out:
#                    ER     IP   ERA       MAP
# Name
# Zack Britton      4.0   67.0  0.54  1.967742
# Blake Treinen     7.0   80.1  0.78  1.975015
# Jacob deGrom     41.0  217.0  1.70  2.091803
# Clayton Kershaw  28.0  149.0  1.69  2.198312
# Jeremy Jeffress  11.0   76.2  1.29  2.241169

# %%
ERA_2016_2018.loc[['Justin Verlander','CC Sabathia', 'Max Scherzer']]
# Out:
#                     ER     IP   ERA       MAP
# Name
# Justin Verlander  60.0  214.0  2.52  2.678808
# Justin Verlander  77.0  227.2  3.04  3.052030
# Justin Verlander  77.0  206.0  3.36  3.272109
# CC Sabathia       78.0  179.2  3.91  3.633982
# CC Sabathia       62.0  153.0  3.65  3.431535
# CC Sabathia       61.0  148.2  3.69  3.463167
# Max Scherzer      62.0  220.2  2.53  2.683323
# Max Scherzer      56.0  200.2  2.51  2.682165
# Max Scherzer      75.0  228.1  2.96  2.986397
