# %%
#!pip install pybaseball

# %%
from pybaseball import statcast
import pandas as pd

# %%
data = statcast(start_dt='2019-05-11', end_dt='2019-05-11')
pd.set_option('display.max_columns', 500)
data.head(20)
# Out:
#     index pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0     167         FC 2019-05-11           86.4        -1.8220         6.0280
# 1     171         FT 2019-05-11           94.2        -1.7036         6.0613
# 2     175         FC 2019-05-11           89.3        -2.1108         5.8809
# 3     179         FT 2019-05-11           93.3        -1.6762         6.0005
# 4     183         FC 2019-05-11           87.6        -2.2382         5.8004
# 5     187         FC 2019-05-11           87.6        -1.8453         5.9592
# 6     191         FT 2019-05-11           92.6        -1.5180         6.0045
# 7     194         FT 2019-05-11           92.8        -1.7449         6.1372
# 8     198         FC 2019-05-11           89.1        -1.9855         5.9756
# 9     202         FC 2019-05-11           87.9        -2.0877         5.9864
# 10    206         FT 2019-05-11           92.9        -1.9172         6.0589
# ...

# %%
data.shape
# Out:
# (4923, 90)

# %%
pd.DataFrame.to_csv()
