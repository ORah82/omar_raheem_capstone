# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mbl
from scipy import stats
# %matplotlib inline

# %%
statcast_2019 = pd.read_csv("/Users/orah82/baseball_cap/data_2019.csv")

# %%
statcast_2018.head()
# Out:
#    Unnamed: 0  index pitch_type   game_date  release_speed  release_pos_x  \
# 0           0    558         FC  2018-04-29           82.4         4.3766
# 1           1    577         FC  2018-04-29           83.1         4.3432
# 2           2    583         SI  2018-04-29           90.9         4.5215
# 3           3    597         SI  2018-04-29           91.7         4.5249
# 4           4    607         SI  2018-04-29           92.5         4.2344
#
#    release_pos_z player_name    batter   pitcher     events      description  \
# 0         4.2375  Aaron Loup  608336.0  571901.0  strikeout  swinging_strike
# 1         4.3577  Aaron Loup  608336.0  571901.0        NaN  swinging_strike
# 2         4.1900  Aaron Loup  608336.0  571901.0        NaN    called_strike
# 3         4.2261  Aaron Loup  608336.0  571901.0        NaN             ball
# 4         4.4870  Aaron Loup  608577.0  571901.0  field_out    hit_into_play
#
# ...

# %%
statcast_2019.head()
# Out:
#    Unnamed: 0  index pitch_type   game_date  release_speed  release_pos_x  \
# 0           0    167         FC  2019-05-11           86.4        -1.8220
# 1           1    169         FT  2019-05-11           94.2        -1.7036
# 2           2    175         FC  2019-05-11           89.3        -2.1108
# 3           3    177         FT  2019-05-11           93.3        -1.6762
# 4           4    183         FC  2019-05-11           87.6        -2.2382
#
#    release_pos_z   player_name    batter   pitcher     events  \
# 0         6.0280  Shane Greene  592696.0  572888.0  strikeout
# 1         6.0613  Shane Greene  592696.0  572888.0        NaN
# 2         5.8809  Shane Greene  592696.0  572888.0        NaN
# 3         6.0005  Shane Greene  592696.0  572888.0        NaN
# 4         5.8004  Shane Greene  592696.0  572888.0        NaN
#
#                description  spin_dir  spin_rate_deprecated  \
# 0  swinging_strike_blocked       NaN                   NaN
# ...

# %%
statcast_2017.drop(columns="Unnamed: 0", inplace=True)
statcast_2017.set_index("index", inplace=True)

# %%
pd.set_option('display.max_columns', 500)
pd.set_option("display.max_rows", 101)

# %%
statcast_2017.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# index
# 151           CH  2017-04-28           83.0        -0.8785         6.3025
# 164           FF  2017-04-28           90.9        -0.9242         6.4893
# 166           FF  2017-04-28           91.4        -0.9547         6.4707
# 175           CH  2017-04-28           82.4        -0.9800         6.4947
# 188           FF  2017-04-28           91.8        -0.8520         6.5040
#
#          player_name    batter   pitcher     events              description  \
# index
# 151    Chase Whitley  475253.0  595032.0  strikeout  swinging_strike_blocked
# 164    Chase Whitley  475253.0  595032.0        NaN                     foul
# 166    Chase Whitley  475253.0  595032.0        NaN                     foul
# 175    Chase Whitley  475253.0  595032.0        NaN                     ball
# 188    Chase Whitley  475253.0  595032.0        NaN                     ball
#
# ...

# %%
['release_speed', 'release_pos_x', 'release_pos_z', 'release_spin', 'pfx_x', 'pfx_z',]

# %%
name = statcast_2017.groupby(["player_name"])

# %%
Justin_2017 = name.get_group('Justin Verlander')

# %%
Justin_2017.shape
# Out:
# (526, 89)

# %%
Justin_2019.shape
# Out:
# (611, 89)

# %%
Justin_2018.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# index
# 18386         FF  2018-04-25           97.5        -1.8947         6.6804
# 18409         FF  2018-04-25           96.7        -1.9084         6.7365
# 18431         FF  2018-04-25           96.6        -1.6602         6.7720
# 18435         FF  2018-04-25           96.5        -1.7319         6.6721
# 18456         FF  2018-04-25           95.8        -1.6248         6.7363
#
#             player_name    batter   pitcher     events          description  \
# index
# 18386  Justin Verlander  472528.0  434378.0  field_out        hit_into_play
# 18409  Justin Verlander  472528.0  434378.0        NaN                 foul
# 18431  Justin Verlander  446359.0  434378.0     double  hit_into_play_score
# 18435  Justin Verlander  446359.0  434378.0        NaN                 foul
# 18456  Justin Verlander  446359.0  434378.0        NaN                 ball
#
# ...

# %%
CC_2018.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# index
# 1044          SL  2018-04-29           79.8         2.5128         6.0048
# 1058          SL  2018-04-29           81.4         2.7989         6.1092
# 1081          SL  2018-04-29           80.6         2.8237         5.9941
# 1102          SI  2018-04-29           89.5         2.5277         6.0032
# 1110          SL  2018-04-29           79.7         2.7162         6.0033
#
#        player_name    batter   pitcher     events    description  spin_dir  \
# index
# 1044   CC Sabathia  435079.0  282332.0  field_out  hit_into_play       NaN
# 1058   CC Sabathia  435079.0  282332.0        NaN   blocked_ball       NaN
# 1081   CC Sabathia  435079.0  282332.0        NaN           foul       NaN
# 1102   CC Sabathia  435079.0  282332.0        NaN           ball       NaN
# 1110   CC Sabathia  435079.0  282332.0        NaN  called_strike       NaN
#
# ...

# %%
Justin_2018.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# index
# 18386         FF  2018-04-25           97.5        -1.8947         6.6804
# 18409         FF  2018-04-25           96.7        -1.9084         6.7365
# 18431         FF  2018-04-25           96.6        -1.6602         6.7720
# 18435         FF  2018-04-25           96.5        -1.7319         6.6721
# 18456         FF  2018-04-25           95.8        -1.6248         6.7363
#
#             player_name    batter   pitcher     events          description  \
# index
# 18386  Justin Verlander  472528.0  434378.0  field_out        hit_into_play
# 18409  Justin Verlander  472528.0  434378.0        NaN                 foul
# 18431  Justin Verlander  446359.0  434378.0     double  hit_into_play_score
# 18435  Justin Verlander  446359.0  434378.0        NaN                 foul
# 18456  Justin Verlander  446359.0  434378.0        NaN                 ball
#
# ...

# %%
Max_2019.shape
# Out:
# (644, 89)

# %%
CC_2019.shape
# Out:
# (496, 89)

# %%
CC_04_30.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# index
# 1615          SL  2019-04-30           80.1         2.3324         5.9379
# 1625          SL  2019-04-30           79.8         2.3933         5.9260
# 1638          FC  2019-04-30           87.0         2.2627         6.0819
# 1653          CH  2019-04-30           82.6         2.2722         5.9267
# 1674          FC  2019-04-30           88.0         2.2764         6.0622
#
#        player_name    batter   pitcher events      description  spin_dir  \
# index
# 1615   CC Sabathia  572233.0  282332.0   walk             ball       NaN
# 1625   CC Sabathia  572233.0  282332.0    NaN     blocked_ball       NaN
# 1638   CC Sabathia  572233.0  282332.0    NaN             ball       NaN
# 1653   CC Sabathia  572233.0  282332.0    NaN             foul       NaN
# 1674   CC Sabathia  572233.0  282332.0    NaN  swinging_strike       NaN
#
# ...

# %%
CC_04_24.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# index
# 1958          FC  2019-04-24           89.0         2.3724         5.9688
# 1975          FC  2019-04-24           88.2         2.2597         6.0470
# 1987          FC  2019-04-24           87.8         2.2438         5.9981
# 2003          CH  2019-04-24           82.2         2.5208         5.8164
# 2016          FC  2019-04-24           87.1         2.2340         6.0796
#
#        player_name    batter   pitcher     events      description  spin_dir  \
# index
# 1958   CC Sabathia  405395.0  282332.0  field_out    hit_into_play       NaN
# 1975   CC Sabathia  405395.0  282332.0        NaN  swinging_strike       NaN
# 1987   CC Sabathia  405395.0  282332.0        NaN             foul       NaN
# 2003   CC Sabathia  592743.0  282332.0  strikeout         foul_tip       NaN
# 2016   CC Sabathia  592743.0  282332.0        NaN             foul       NaN
#
# ...

# %%
CC_05_11 = CC

# %%
CC_05_11.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# index
# 2581          FS  2019-05-11           77.8         2.5341         5.9599
# 2598          FC  2019-05-11           88.5         2.3939         6.0263
# 2604          FC  2019-05-11           87.0         2.4801         6.0538
# 2619          FC  2019-05-11           87.7         2.4768         6.0518
# 2639          FF  2019-05-11           87.5         2.4485         6.0437
#
#        player_name    batter   pitcher     events      description  spin_dir  \
# index
# 2581   CC Sabathia  621002.0  282332.0  field_out    hit_into_play       NaN
# 2598   CC Sabathia  621002.0  282332.0        NaN  swinging_strike       NaN
# 2604   CC Sabathia  502054.0  282332.0  field_out    hit_into_play       NaN
# 2619   CC Sabathia  502054.0  282332.0        NaN    called_strike       NaN
# 2639   CC Sabathia  650490.0  282332.0  field_out    hit_into_play       NaN
#
# ...

# %%
CC_05_06.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# index
# 1459          SI  2019-05-06           88.7         2.1827         5.9132
# 1474          SI  2019-05-06           89.5         2.4142         5.7504
# 1479          SI  2019-05-06           88.4         2.3909         5.8433
# 1494          FC  2019-05-06           88.4         2.2587         5.9156
# 1513          SL  2019-05-06           79.4         2.3855         5.8150
#
#        player_name    batter   pitcher     events    description  spin_dir  \
# index
# 1459   CC Sabathia  457803.0  282332.0  field_out  hit_into_play       NaN
# 1474   CC Sabathia  457803.0  282332.0        NaN  called_strike       NaN
# 1479   CC Sabathia  570267.0  282332.0       walk           ball       NaN
# 1494   CC Sabathia  570267.0  282332.0        NaN           ball       NaN
# 1513   CC Sabathia  570267.0  282332.0        NaN           ball       NaN
#
# ...

# %%
CC_2019['pitch_number'].plot('hist')

# %%
Max_2019.head()
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# index
# 1540          FF  2019-05-11           95.7        -3.5944         5.0019
# 1562          FF  2019-05-11           96.0        -3.6483         4.9039
# 1564          FF  2019-05-11           95.9        -3.7279         4.9867
# 1589          FF  2019-05-11           95.1        -3.6901         4.9656
# 1609          CH  2019-05-11           83.0        -3.5973         4.9943
#
#         player_name    batter   pitcher     events      description  spin_dir  \
# index
# 1540   Max Scherzer  571970.0  453286.0  field_out    hit_into_play       NaN
# 1562   Max Scherzer  571970.0  453286.0        NaN             ball       NaN
# 1564   Max Scherzer  571970.0  453286.0        NaN  swinging_strike       NaN
# 1589   Max Scherzer  571970.0  453286.0        NaN    called_strike       NaN
# 1609   Max Scherzer  571970.0  453286.0        NaN             ball       NaN
#
# ...

# %%
fig, ax = plt.subplots(
    nrows = 3,
    ncols = 2,
    figsize = (10, 10)
)

Justin_2019['release_speed'].plot(kind='hist', ax = ax[0,0])
Justin_2019['launch_speed'].plot(kind='hist', ax = ax[0,1])


CC_2019['release_speed'].plot(kind="hist", ax = ax[1, 0])
CC_2019['launch_speed'].plot(kind="hist", ax = ax[1, 1])

Max_2019['release_speed'].plot(kind="hist", ax = ax[2, 0])
Max_2019['launch_speed'].plot(kind="hist", ax = ax[2, 1])

# %%
features = ['pitch_name', 'pitch_number'
                    ,'des', 'description']

# %%
CC_2019[features]
# Out:
#             pitch_name  pitch_number  \
# index
# 2574      Split Finger           2.0
# 2599            Cutter           1.0
# 2604            Cutter           2.0
# 2627            Cutter           1.0
# 2639   4-Seam Fastball           3.0
# 2657            Cutter           2.0
# 2667            Cutter           1.0
# 2978      Split Finger           2.0
# 3001            Slider           1.0
# 3006            Cutter           3.0
# 3027            Cutter           2.0
# 3039   4-Seam Fastball           1.0
# 3061            Cutter           3.0
# 3071            Cutter           2.0
# 3089            Slider           1.0
# 3103            Sinker           3.0
# 3127            Slider           2.0
# 3131            Slider           1.0
# 3348            Cutter           4.0
# 3363            Cutter           3.0
# 3384            Cutter           2.0
# 3388          Changeup           1.0
# 3416          Changeup           2.0
# 3433            Cutter           1.0
# ...

# %%
sns.scatterplot(x=, y=, data=)

# %%
may_statcast.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
player_id = pd.read_csv('baseball_cap/player_id.csv', encoding = "ISO-8859-1")

# %%
player_id.head(15)
# Out:
#     mlb_id       mlb_name mlb_pos mlb_team         mlb_team_long bats throws  \
# 0   592091    A.J. Achter       P      LAA    Los Angeles Angels    R      R
# 1   595918      A.J. Cole       P      CLE     Cleveland Indians    R      R
# 2   454560     A.J. Ellis       C       SD      San Diego Padres    R      R
# 3   456167   A.J. Griffin       P      TEX         Texas Rangers    R      R
# 4   543362   A.J. Jimenez       C      TEX         Texas Rangers    R      R
# 5   621345    A.J. Minter       P      ATL        Atlanta Braves    L      L
# 6   571963    A.J. Morris       P      CIN       Cincinnati Reds    R      R
# 7   572041   A.J. Pollock      CF      LAD   Los Angeles Dodgers    R      R
# 8   519263   A.J. Schugel       P      PIT    Pittsburgh Pirates    R      R
# 9   571437  Aaron Altherr      CF       SF  San Francisco Giants    R      R
# 10  502578  Aaron Barrett       P      WSH  Washington Nationals    R      R
# ...
